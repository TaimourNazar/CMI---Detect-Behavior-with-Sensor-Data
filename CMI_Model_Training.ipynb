# %% [markdown]
# <a href="https://www.kaggle.com/code/taimour/cmi-booster-training?scriptVersionId=252363292" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # <div style="color:#2d83ed; font-family: 'Segoe UI'; text-align: center; border-top:5px solid green; padding-left:10px; background-color:#F8F9F9; padding:10px; border-radius:5px;font-weight: bold">🚆 Model Training</div>
#
# For Competition notebook visit ---> [https://www.kaggle.com/code/taimour/cmi-deep-dive-eda-boosters](https://www.kaggle.com/code/taimour/cmi-deep-dive-eda-boosters)
#
# Due to time limitations, model was trained separately in this notebook.

# %% [markdown]
# # <div style="color:#2d83ed; font-family: 'Segoe UI'; text-align: center; border-top:5px solid green; padding-left:10px; background-color:#F8F9F9; padding:10px; border-radius:5px;font-weight: bold">📚 Libraries / Packages</div>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
import polars as pl
import kaggle_evaluation.cmi_inference_server
import joblib

import catboost
from catboost import CatBoostClassifier
import lightgbm as lgb
import xgboost as xgb

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, f1_score
from scipy.spatial.transform import Rotation as R

from sklearn.preprocessing import LabelEncoder, RobustScaler
from sklearn.impute import KNNImputer
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline

# %% [markdown]
# # <div style="color:#2d83ed; font-family: 'Segoe UI'; text-align: center; border-top:5px solid green; padding-left:10px; background-color:#F8F9F9; padding:10px; border-radius:5px;font-weight: bold">📖 Load Data</div>

# %%
cleaned_data = pl.read_csv('/kaggle/input/cmi-detect-behavior-with-sensor-data-cleaned/cmi_bfrb_cleaned_data_full.csv')
# train = pl.read_csv('/kaggle/input/cmi-detect-behavior-with-sensor-data/train.csv')
# train_demo = pl.read_csv('/kaggle/input/cmi-detect-behavior-with-sensor-data/train_demographics.csv')

# # Drop these columns from training data
# train = train.drop(['phase', 'orientation', 'behavior', 'sequence_type'])

# train = train.join(train_demo,on="subject",how="left")

# %% [markdown]
# # <div style="color:#2d83ed; font-family: 'Segoe UI'; text-align: center; border-top:5px solid green; padding-left:10px; background-color:#F8F9F9; padding:10px; border-radius:5px;font-weight: bold">💎 Feature Engineering</div>
#
# **Helper Functions**

# %%
def remove_gravity_from_acc(acc_data, rot_data):

    if isinstance(acc_data, pd.DataFrame):
        acc_values = acc_data[['acc_x', 'acc_y', 'acc_z']].values
    else:
        acc_values = acc_data

    if isinstance(rot_data, pd.DataFrame):
        quat_values = rot_data[['rot_x', 'rot_y', 'rot_z', 'rot_w']].values
    else:
        quat_values = rot_data

    num_samples = acc_values.shape[0]
    linear_accel = np.zeros_like(acc_values)
    
    gravity_world = np.array([0, 0, 9.81])

    for i in range(num_samples):
        if np.all(np.isnan(quat_values[i])) or np.all(np.isclose(quat_values[i], 0)):
            linear_accel[i, :] = acc_values[i, :] 
            continue

        try:
            rotation = R.from_quat(quat_values[i])
            gravity_sensor_frame = rotation.apply(gravity_world, inverse=True)
            linear_accel[i, :] = acc_values[i, :] - gravity_sensor_frame
        except ValueError:
             linear_accel[i, :] = acc_values[i, :]
             
    return linear_accel

def calculate_angular_velocity_from_quat(rot_data, time_delta=1/200): # Assuming 200Hz sampling rate
    if isinstance(rot_data, pd.DataFrame):
        quat_values = rot_data[['rot_x', 'rot_y', 'rot_z', 'rot_w']].values
    else:
        quat_values = rot_data

    num_samples = quat_values.shape[0]
    angular_vel = np.zeros((num_samples, 3))

    for i in range(num_samples - 1):
        q_t = quat_values[i]
        q_t_plus_dt = quat_values[i+1]

        if np.all(np.isnan(q_t)) or np.all(np.isclose(q_t, 0)) or \
           np.all(np.isnan(q_t_plus_dt)) or np.all(np.isclose(q_t_plus_dt, 0)):
            continue

        try:
            rot_t = R.from_quat(q_t)
            rot_t_plus_dt = R.from_quat(q_t_plus_dt)

            # Calculate the relative rotation
            delta_rot = rot_t.inv() * rot_t_plus_dt
            
            # Convert delta rotation to angular velocity vector
            # The rotation vector (Euler axis * angle) scaled by 1/dt
            # is a good approximation for small delta_rot
            angular_vel[i, :] = delta_rot.as_rotvec() / time_delta
        except ValueError:
            # If quaternion is invalid, angular velocity remains zero
            pass
            
    return angular_vel

def calculate_angular_distance(rot_data):
    if isinstance(rot_data, pd.DataFrame):
        quat_values = rot_data[['rot_x', 'rot_y', 'rot_z', 'rot_w']].values
    else:
        quat_values = rot_data

    num_samples = quat_values.shape[0]
    angular_dist = np.zeros(num_samples)

    for i in range(num_samples - 1):
        q1 = quat_values[i]
        q2 = quat_values[i+1]

        if np.all(np.isnan(q1)) or np.all(np.isclose(q1, 0)) or \
           np.all(np.isnan(q2)) or np.all(np.isclose(q2, 0)):
            angular_dist[i] = 0 # Или np.nan, в зависимости от желаемого поведения
            continue
        try:
            # Converting quaternions to Rotation objects
            r1 = R.from_quat(q1)
            r2 = R.from_quat(q2)

            # Calculating the angular distance: 2 * arccos(|real(p * q*)|)
            # where q* is the conjugate of quaternion q
            # In scipy.spatial.transform.Rotation, r1.inv() * r2 gives the relative rotation.
            # The angle of this relative rotation is the angular distance.
            relative_rotation = r1.inv() * r2
            
            # The angle of the rotation vector corresponds to the angular distance
            # The norm of the rotation vector is the angle in radians
            angle = np.linalg.norm(relative_rotation.as_rotvec())
            angular_dist[i] = angle
        except ValueError:
            angular_dist[i] = 0 # In case of invalid quaternions
            pass
            
    return angular_dist

# %% [markdown]
# **IMU**

# %%
def feature_engineering_imu(data:pl.DataFrame):
    data = data.to_pandas()
    data['acc_mag'] = np.sqrt(data['acc_x']**2 + data['acc_y']**2 + data['acc_z']**2)
    data['rot_angle'] = 2 * np.arccos(data['rot_w'].clip(-1, 1))
    data['acc_mag_jerk'] = data.groupby('sequence_id')['acc_mag'].diff().fillna(0)
    data['rot_angle_vel'] = data.groupby('sequence_id')['rot_angle'].diff().fillna(0)

    linear_accel_list = []
    for _, group in data.groupby('sequence_id'):
        acc_data_group = group[['acc_x', 'acc_y', 'acc_z']]
        rot_data_group = group[['rot_x', 'rot_y', 'rot_z', 'rot_w']]
        linear_accel_group = remove_gravity_from_acc(acc_data_group, rot_data_group)
        linear_accel_list.append(pd.DataFrame(linear_accel_group, columns=['linear_acc_x', 'linear_acc_y', 'linear_acc_z'], index=group.index))
    
    df_linear_accel = pd.concat(linear_accel_list)
    data = pd.concat([data, df_linear_accel], axis=1)
    data['linear_acc_mag'] = np.sqrt(data['linear_acc_x']**2 + data['linear_acc_y']**2 + data['linear_acc_z']**2)
    data['linear_acc_mag_jerk'] = data.groupby('sequence_id')['linear_acc_mag'].diff().fillna(0)
    angular_vel_list = []
    for _, group in data.groupby('sequence_id'):
        rot_data_group = group[['rot_x', 'rot_y', 'rot_z', 'rot_w']]
        angular_vel_group = calculate_angular_velocity_from_quat(rot_data_group)
        angular_vel_list.append(pd.DataFrame(angular_vel_group, columns=['angular_vel_x', 'angular_vel_y', 'angular_vel_z'], index=group.index))
    
    df_angular_vel = pd.concat(angular_vel_list)
    data = pd.concat([data, df_angular_vel], axis=1)
    
    print("  Calculating angular distance between successive quaternions...")
    angular_distance_list = []
    for _, group in data.groupby('sequence_id'):
        rot_data_group = group[['rot_x', 'rot_y', 'rot_z', 'rot_w']]
        angular_dist_group = calculate_angular_distance(rot_data_group)
        angular_distance_list.append(pd.DataFrame(angular_dist_group, columns=['angular_distance'], index=group.index))
    
    df_angular_distance = pd.concat(angular_distance_list)
    data = pd.concat([data, df_angular_distance], axis=1)
    data = pl.from_pandas(data)
    return data

# %%
# train = feature_engineering_imu(train)

# %%
# train.head(2)

# %% [markdown]
# **Statistical**

# %%
def feature_engineering_stat(data:pl.DataFrame):
    non_sensor_cols = []
    if "gesture" in data.columns:
        non_sensor_cols = ["gesture"]
        
    # All numeric sensor columns (everything except id, demo, target)
    stat_cols = [
        c for c in data.columns
        if c not in non_sensor_cols + ["sequence_id", "row_id","sequence_counter","subject"]
    ]
    
    # Build aggregation expressions
    agg_exprs = []
    
    # full-stats bundle for sensor columns
    for c in stat_cols:
        agg_exprs += [
            pl.col(c).mean().alias(f"{c}_mean"),
            pl.col(c).std().alias(f"{c}_std"),
            pl.col(c).var().alias(f"{c}_var"),
            pl.col(c).quantile(0.25).alias(f"{c}_q25"),
            pl.col(c).median().alias(f"{c}_q50"),
            pl.col(c).quantile(0.75).alias(f"{c}_q75"),
            pl.col(c).max().alias(f"{c}_max"),
            pl.col(c).min().alias(f"{c}_min"),
            pl.col(c).first().alias(f"{c}_first"),
            pl.col(c).last().alias(f"{c}_last"),
            pl.col(c).quantile(0.25, "nearest").alias(f"{c}_t25"),
            pl.col(c).quantile(0.75, "nearest").alias(f"{c}_t75"),
            (pl.col(c).last() - pl.col(c).first()).alias(f"{c}_delta"),
            pl.corr("sequence_counter", c).alias(f"{c}_corr_time"),
            pl.col(c).diff().mean().alias(f"{c}_diff_mean"),
            pl.col(c).diff().std().alias(f"{c}_diff_std"),
            pl.col(c).skew().alias(f"{c}_skew"),
            pl.col(c).kurtosis().alias(f"{c}_kurt"),
            pl.col(c).diff().abs().gt(0).sum().alias(f"{c}_n_changes")
        ]
        agg_exprs += [
            pl.when(pl.col("sequence_counter") < 0.1 * pl.max("sequence_counter"))
              .then(pl.col(c)).otherwise(None).mean().alias(f"{c}_seg1_mean"),
            pl.when(pl.col("sequence_counter") > 0.9 * pl.max("sequence_counter"))
              .then(pl.col(c)).otherwise(None).mean().alias(f"{c}_seg3_mean"),
        ]
    
    # first() for demographics and target
    agg_exprs += [
        pl.col(c).first().alias(c) for c in non_sensor_cols
    ]
    
    # Group-by and aggregate
    cleaned_data = (
        data
        .group_by("sequence_id", maintain_order=True)
        .agg(agg_exprs)
    )
    return cleaned_data

# %%
# train_demographic_target_cols = [
#     "gesture"
#     ]
# cleaned_data = feature_engineering_stat(train)
# cleaned_data.shape

# %%
# cleaned_data.write_csv('cmi_bfrb_cleaned_data_full.csv')

# %% [markdown]
# # <div style="color:#2d83ed; font-family: 'Segoe UI'; text-align: center; border-top:5px solid green; padding-left:10px; background-color:#F8F9F9; padding:10px; border-radius:5px;font-weight: bold">🎯 Scaling & Encoding</div>

# %%
# Assume cleaned_data is already a Polars DataFrame
target_col = "gesture"

# --- Convert Polars DataFrame to Pandas only if needed ---
# CatBoost does not yet fully support Polars directly
df = cleaned_data.to_pandas()

# --- Define X and y properly ---
X = df.drop(columns=[target_col, "sequence_id"])  # Feature matrix
y = df[target_col].values # Target
# Estimate number of classes from your target variable `y`
num_classes = len(set(y))  # or len(np.unique(y))

# Encode target
le = LabelEncoder()
y = le.fit_transform(y)

joblib.dump(le, 'Target_LabelEncoder.joblib')
# Out:
# ['Target_LabelEncoder.joblib']

# %%
#Initialize the scaler
robustscaler = RobustScaler()
# Fit on the integer columns of training data (changed to numpy array)
X_scaled = robustscaler.fit_transform(X)
#numpy array convert to panda's dataframe
X = pd.DataFrame(X_scaled, columns=X.columns)

joblib.dump(robustscaler, 'robustscaler.joblib')
# Out:
# /usr/local/lib/python3.11/dist-packages/numpy/lib/nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a, func=_nanmedian, keepdims=keepdims,
# /usr/local/lib/python3.11/dist-packages/numpy/lib/nanfunctions.py:1384: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_data.py:114: RuntimeWarning: invalid value encountered in less
#   constant_mask = scale < 10 * np.finfo(scale.dtype).eps
# ['robustscaler.joblib']

# %% [markdown]
# # <div style="color:#2d83ed; font-family: 'Segoe UI'; text-align: center; border-top:5px solid green; padding-left:10px; background-color:#F8F9F9; padding:10px; border-radius:5px;font-weight: bold">🚅 Train the Model</div>

# %%
params_cat = {
    'loss_function': 'MultiClass',
    'learning_rate': 0.06,
    'iterations': 2000,
    'task_type': 'GPU',
    'verbose' : False
}    

params_lgb = {
    'objective': 'multiclass',
    'num_class': num_classes,
    'learning_rate': 0.1,
    'n_estimators': 600,
    'max_bin' : 20,
    'num_threads' : -1,
    'device': 'gpu',  # Requires LightGBM with GPU support compiled
    'verbose': -1      # Silence output; set to 1 to see progress
}

params_xgb = {
    'objective': 'multi:softprob',        # Equivalent to multiclass in LightGBM; outputs probabilities
    'num_class': num_classes,             # Required for multi-class in XGBoost
    'learning_rate': 0.1,                 # Same as LightGBM's learning_rate
    'n_estimators': 600,                  # Same number of boosting rounds
    'max_bin': 256,                       # XGBoost default is higher; LightGBM uses 20, but XGBoost typically uses 256
    'n_jobs': -1,                         # Equivalent to num_threads in LightGBM
    'tree_method': 'gpu_hist',            # Enables GPU; requires XGBoost with GPU support
    'verbosity': 0,                       # 0 = silent, 1 = info (similar to verbose=-1 in LightGBM)
    'eval_metric': 'mlogloss'             # Optional: for monitoring; multiclass logloss
}

# %%
# CAT Set up stratified KFold
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
fold_acc, fold_f1 = [], []

for fold, (train_idx, val_idx) in enumerate(kfold.split(X, y), start=1):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    # final_model = CatBoostClassifier(**params_cat)
    # final_model = lgb.LGBMClassifier(**params_lgb)
    final_model = xgb.XGBClassifier(**params_xgb)
    
    final_model.fit(X_train, y_train, eval_set=[(X_val, y_val)])
    y_pred = final_model.predict(X_val)

    acc = accuracy_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred, average="macro")

    fold_acc.append(acc)
    fold_f1.append(f1)
    print(f"Fold {fold}: Accuracy={acc:.4f}, Macro-F1={f1:.4f}")

print("\n======  5-Fold Summary  ======")
print(f"Accuracy:  mean={np.mean(fold_acc):.4f}  std={np.std(fold_acc):.4f}")
print(f"Macro-F1 : mean={np.mean(fold_f1):.4f}  std={np.std(fold_f1):.4f}")
# Out:
# [0]	validation_0-mlogloss:2.61893
# [1]	validation_0-mlogloss:2.44453
# [2]	validation_0-mlogloss:2.30944
# [3]	validation_0-mlogloss:2.20360
# [4]	validation_0-mlogloss:2.11648
# [5]	validation_0-mlogloss:2.03562
# [6]	validation_0-mlogloss:1.96632
# [7]	validation_0-mlogloss:1.90190
# [8]	validation_0-mlogloss:1.84278
# [9]	validation_0-mlogloss:1.78919
# [10]	validation_0-mlogloss:1.73970
# [11]	validation_0-mlogloss:1.69487
# [12]	validation_0-mlogloss:1.65312
# [13]	validation_0-mlogloss:1.61454
# [14]	validation_0-mlogloss:1.57878
# [15]	validation_0-mlogloss:1.54633
# [16]	validation_0-mlogloss:1.51429
# [17]	validation_0-mlogloss:1.48562
# [18]	validation_0-mlogloss:1.45854
# [19]	validation_0-mlogloss:1.43162
# [20]	validation_0-mlogloss:1.40749
# [21]	validation_0-mlogloss:1.38425
# [22]	validation_0-mlogloss:1.36257
# [23]	validation_0-mlogloss:1.34298
# [24]	validation_0-mlogloss:1.32367
# [25]	validation_0-mlogloss:1.30615
# [26]	validation_0-mlogloss:1.28983
# [27]	validation_0-mlogloss:1.27228
# [28]	validation_0-mlogloss:1.25652
# [29]	validation_0-mlogloss:1.24179
# [30]	validation_0-mlogloss:1.22740
# [31]	validation_0-mlogloss:1.21429
# [32]	validation_0-mlogloss:1.20120
# [33]	validation_0-mlogloss:1.19016
# [34]	validation_0-mlogloss:1.18054
# [35]	validation_0-mlogloss:1.16868
# [36]	validation_0-mlogloss:1.15859
# [37]	validation_0-mlogloss:1.14850
# [38]	validation_0-mlogloss:1.13836
# [39]	validation_0-mlogloss:1.13003
# [40]	validation_0-mlogloss:1.12099
# [41]	validation_0-mlogloss:1.11239
# [42]	validation_0-mlogloss:1.10379
# [43]	validation_0-mlogloss:1.09594
# [44]	validation_0-mlogloss:1.08745
# [45]	validation_0-mlogloss:1.08036
# [46]	validation_0-mlogloss:1.07272
# [47]	validation_0-mlogloss:1.06610
# [48]	validation_0-mlogloss:1.05899
# [49]	validation_0-mlogloss:1.05275
# [50]	validation_0-mlogloss:1.04706
# [51]	validation_0-mlogloss:1.04091
# [52]	validation_0-mlogloss:1.03460
# [53]	validation_0-mlogloss:1.02884
# [54]	validation_0-mlogloss:1.02421
# [55]	validation_0-mlogloss:1.01842
# [56]	validation_0-mlogloss:1.01325
# [57]	validation_0-mlogloss:1.00979
# [58]	validation_0-mlogloss:1.00486
# [59]	validation_0-mlogloss:1.00126
# [60]	validation_0-mlogloss:0.99677
# [61]	validation_0-mlogloss:0.99170
# [62]	validation_0-mlogloss:0.98783
# [63]	validation_0-mlogloss:0.98449
# [64]	validation_0-mlogloss:0.98101
# [65]	validation_0-mlogloss:0.97713
# [66]	validation_0-mlogloss:0.97289
# [67]	validation_0-mlogloss:0.96988
# [68]	validation_0-mlogloss:0.96722
# [69]	validation_0-mlogloss:0.96380
# [70]	validation_0-mlogloss:0.96074
# [71]	validation_0-mlogloss:0.95733
# [72]	validation_0-mlogloss:0.95368
# [73]	validation_0-mlogloss:0.95070
# [74]	validation_0-mlogloss:0.94862
# [75]	validation_0-mlogloss:0.94613
# [76]	validation_0-mlogloss:0.94386
# [77]	validation_0-mlogloss:0.94079
# [78]	validation_0-mlogloss:0.93894
# [79]	validation_0-mlogloss:0.93694
# [80]	validation_0-mlogloss:0.93437
# [81]	validation_0-mlogloss:0.93279
# [82]	validation_0-mlogloss:0.92994
# [83]	validation_0-mlogloss:0.92808
# [84]	validation_0-mlogloss:0.92589
# [85]	validation_0-mlogloss:0.92372
# [86]	validation_0-mlogloss:0.92112
# [87]	validation_0-mlogloss:0.91932
# [88]	validation_0-mlogloss:0.91695
# [89]	validation_0-mlogloss:0.91571
# [90]	validation_0-mlogloss:0.91429
# [91]	validation_0-mlogloss:0.91318
# [92]	validation_0-mlogloss:0.91183
# [93]	validation_0-mlogloss:0.91068
# [94]	validation_0-mlogloss:0.90943
# [95]	validation_0-mlogloss:0.90819
# [96]	validation_0-mlogloss:0.90721
# [97]	validation_0-mlogloss:0.90566
# [98]	validation_0-mlogloss:0.90403
# [99]	validation_0-mlogloss:0.90264
# [100]	validation_0-mlogloss:0.90171
# [101]	validation_0-mlogloss:0.90039
# [102]	validation_0-mlogloss:0.89964
# [103]	validation_0-mlogloss:0.89865
# [104]	validation_0-mlogloss:0.89689
# [105]	validation_0-mlogloss:0.89589
# [106]	validation_0-mlogloss:0.89512
# [107]	validation_0-mlogloss:0.89420
# [108]	validation_0-mlogloss:0.89377
# [109]	validation_0-mlogloss:0.89299
# [110]	validation_0-mlogloss:0.89156
# [111]	validation_0-mlogloss:0.89070
# [112]	validation_0-mlogloss:0.89031
# [113]	validation_0-mlogloss:0.88949
# [114]	validation_0-mlogloss:0.88890
# [115]	validation_0-mlogloss:0.88784
# [116]	validation_0-mlogloss:0.88644
# [117]	validation_0-mlogloss:0.88634
# [118]	validation_0-mlogloss:0.88578
# [119]	validation_0-mlogloss:0.88477
# [120]	validation_0-mlogloss:0.88370
# [121]	validation_0-mlogloss:0.88309
# [122]	validation_0-mlogloss:0.88203
# [123]	validation_0-mlogloss:0.88091
# [124]	validation_0-mlogloss:0.87989
# [125]	validation_0-mlogloss:0.87927
# [126]	validation_0-mlogloss:0.87839
# [127]	validation_0-mlogloss:0.87770
# [128]	validation_0-mlogloss:0.87718
# [129]	validation_0-mlogloss:0.87669
# [130]	validation_0-mlogloss:0.87600
# [131]	validation_0-mlogloss:0.87503
# [132]	validation_0-mlogloss:0.87441
# [133]	validation_0-mlogloss:0.87376
# [134]	validation_0-mlogloss:0.87346
# [135]	validation_0-mlogloss:0.87326
# [136]	validation_0-mlogloss:0.87289
# [137]	validation_0-mlogloss:0.87241
# [138]	validation_0-mlogloss:0.87198
# [139]	validation_0-mlogloss:0.87160
# [140]	validation_0-mlogloss:0.87091
# [141]	validation_0-mlogloss:0.87003
# [142]	validation_0-mlogloss:0.86965
# [143]	validation_0-mlogloss:0.86921
# [144]	validation_0-mlogloss:0.86852
# [145]	validation_0-mlogloss:0.86830
# [146]	validation_0-mlogloss:0.86796
# [147]	validation_0-mlogloss:0.86721
# [148]	validation_0-mlogloss:0.86692
# [149]	validation_0-mlogloss:0.86698
# [150]	validation_0-mlogloss:0.86671
# [151]	validation_0-mlogloss:0.86638
# [152]	validation_0-mlogloss:0.86606
# [153]	validation_0-mlogloss:0.86553
# [154]	validation_0-mlogloss:0.86534
# [155]	validation_0-mlogloss:0.86503
# [156]	validation_0-mlogloss:0.86476
# [157]	validation_0-mlogloss:0.86456
# [158]	validation_0-mlogloss:0.86408
# [159]	validation_0-mlogloss:0.86390
# [160]	validation_0-mlogloss:0.86368
# [161]	validation_0-mlogloss:0.86375
# [162]	validation_0-mlogloss:0.86368
# [163]	validation_0-mlogloss:0.86340
# [164]	validation_0-mlogloss:0.86308
# [165]	validation_0-mlogloss:0.86293
# [166]	validation_0-mlogloss:0.86233
# [167]	validation_0-mlogloss:0.86224
# [168]	validation_0-mlogloss:0.86178
# [169]	validation_0-mlogloss:0.86151
# [170]	validation_0-mlogloss:0.86135
# [171]	validation_0-mlogloss:0.86120
# [172]	validation_0-mlogloss:0.86111
# [173]	validation_0-mlogloss:0.86139
# [174]	validation_0-mlogloss:0.86126
# [175]	validation_0-mlogloss:0.86120
# [176]	validation_0-mlogloss:0.86120
# [177]	validation_0-mlogloss:0.86071
# [178]	validation_0-mlogloss:0.86045
# [179]	validation_0-mlogloss:0.86023
# [180]	validation_0-mlogloss:0.86024
# [181]	validation_0-mlogloss:0.86000
# [182]	validation_0-mlogloss:0.86005
# [183]	validation_0-mlogloss:0.85973
# [184]	validation_0-mlogloss:0.85936
# [185]	validation_0-mlogloss:0.85882
# [186]	validation_0-mlogloss:0.85867
# [187]	validation_0-mlogloss:0.85826
# [188]	validation_0-mlogloss:0.85804
# [189]	validation_0-mlogloss:0.85787
# [190]	validation_0-mlogloss:0.85746
# [191]	validation_0-mlogloss:0.85754
# [192]	validation_0-mlogloss:0.85713
# [193]	validation_0-mlogloss:0.85702
# [194]	validation_0-mlogloss:0.85710
# [195]	validation_0-mlogloss:0.85734
# [196]	validation_0-mlogloss:0.85684
# [197]	validation_0-mlogloss:0.85686
# [198]	validation_0-mlogloss:0.85645
# [199]	validation_0-mlogloss:0.85663
# [200]	validation_0-mlogloss:0.85653
# [201]	validation_0-mlogloss:0.85641
# [202]	validation_0-mlogloss:0.85623
# [203]	validation_0-mlogloss:0.85590
# [204]	validation_0-mlogloss:0.85582
# [205]	validation_0-mlogloss:0.85563
# [206]	validation_0-mlogloss:0.85576
# [207]	validation_0-mlogloss:0.85576
# [208]	validation_0-mlogloss:0.85572
# [209]	validation_0-mlogloss:0.85566
# [210]	validation_0-mlogloss:0.85567
# [211]	validation_0-mlogloss:0.85567
# [212]	validation_0-mlogloss:0.85550
# [213]	validation_0-mlogloss:0.85566
# [214]	validation_0-mlogloss:0.85538
# [215]	validation_0-mlogloss:0.85540
# [216]	validation_0-mlogloss:0.85563
# [217]	validation_0-mlogloss:0.85587
# [218]	validation_0-mlogloss:0.85579
# [219]	validation_0-mlogloss:0.85584
# [220]	validation_0-mlogloss:0.85602
# [221]	validation_0-mlogloss:0.85604
# [222]	validation_0-mlogloss:0.85602
# [223]	validation_0-mlogloss:0.85621
# [224]	validation_0-mlogloss:0.85617
# [225]	validation_0-mlogloss:0.85623
# [226]	validation_0-mlogloss:0.85615
# [227]	validation_0-mlogloss:0.85603
# [228]	validation_0-mlogloss:0.85605
# [229]	validation_0-mlogloss:0.85609
# [230]	validation_0-mlogloss:0.85624
# [231]	validation_0-mlogloss:0.85633
# [232]	validation_0-mlogloss:0.85640
# [233]	validation_0-mlogloss:0.85575
# [234]	validation_0-mlogloss:0.85575
# [235]	validation_0-mlogloss:0.85559
# [236]	validation_0-mlogloss:0.85566
# [237]	validation_0-mlogloss:0.85557
# [238]	validation_0-mlogloss:0.85579
# [239]	validation_0-mlogloss:0.85575
# [240]	validation_0-mlogloss:0.85561
# [241]	validation_0-mlogloss:0.85539
# [242]	validation_0-mlogloss:0.85540
# [243]	validation_0-mlogloss:0.85550
# [244]	validation_0-mlogloss:0.85570
# [245]	validation_0-mlogloss:0.85584
# [246]	validation_0-mlogloss:0.85599
# [247]	validation_0-mlogloss:0.85583
# [248]	validation_0-mlogloss:0.85604
# [249]	validation_0-mlogloss:0.85584
# [250]	validation_0-mlogloss:0.85592
# [251]	validation_0-mlogloss:0.85584
# [252]	validation_0-mlogloss:0.85585
# [253]	validation_0-mlogloss:0.85583
# [254]	validation_0-mlogloss:0.85586
# [255]	validation_0-mlogloss:0.85579
# [256]	validation_0-mlogloss:0.85567
# [257]	validation_0-mlogloss:0.85566
# [258]	validation_0-mlogloss:0.85567
# [259]	validation_0-mlogloss:0.85576
# [260]	validation_0-mlogloss:0.85566
# [261]	validation_0-mlogloss:0.85567
# [262]	validation_0-mlogloss:0.85566
# [263]	validation_0-mlogloss:0.85550
# [264]	validation_0-mlogloss:0.85529
# [265]	validation_0-mlogloss:0.85544
# [266]	validation_0-mlogloss:0.85531
# [267]	validation_0-mlogloss:0.85523
# [268]	validation_0-mlogloss:0.85551
# [269]	validation_0-mlogloss:0.85544
# [270]	validation_0-mlogloss:0.85545
# [271]	validation_0-mlogloss:0.85563
# [272]	validation_0-mlogloss:0.85546
# [273]	validation_0-mlogloss:0.85559
# [274]	validation_0-mlogloss:0.85550
# [275]	validation_0-mlogloss:0.85530
# [276]	validation_0-mlogloss:0.85535
# [277]	validation_0-mlogloss:0.85541
# [278]	validation_0-mlogloss:0.85544
# [279]	validation_0-mlogloss:0.85555
# [280]	validation_0-mlogloss:0.85561
# [281]	validation_0-mlogloss:0.85582
# [282]	validation_0-mlogloss:0.85558
# [283]	validation_0-mlogloss:0.85545
# [284]	validation_0-mlogloss:0.85574
# [285]	validation_0-mlogloss:0.85583
# [286]	validation_0-mlogloss:0.85559
# [287]	validation_0-mlogloss:0.85564
# [288]	validation_0-mlogloss:0.85578
# [289]	validation_0-mlogloss:0.85583
# [290]	validation_0-mlogloss:0.85574
# [291]	validation_0-mlogloss:0.85589
# [292]	validation_0-mlogloss:0.85593
# [293]	validation_0-mlogloss:0.85592
# [294]	validation_0-mlogloss:0.85593
# [295]	validation_0-mlogloss:0.85604
# [296]	validation_0-mlogloss:0.85605
# [297]	validation_0-mlogloss:0.85619
# [298]	validation_0-mlogloss:0.85660
# [299]	validation_0-mlogloss:0.85664
# [300]	validation_0-mlogloss:0.85682
# [301]	validation_0-mlogloss:0.85684
# [302]	validation_0-mlogloss:0.85657
# [303]	validation_0-mlogloss:0.85643
# [304]	validation_0-mlogloss:0.85627
# [305]	validation_0-mlogloss:0.85601
# [306]	validation_0-mlogloss:0.85593
# [307]	validation_0-mlogloss:0.85595
# [308]	validation_0-mlogloss:0.85616
# [309]	validation_0-mlogloss:0.85616
# [310]	validation_0-mlogloss:0.85614
# [311]	validation_0-mlogloss:0.85616
# [312]	validation_0-mlogloss:0.85622
# [313]	validation_0-mlogloss:0.85617
# [314]	validation_0-mlogloss:0.85614
# [315]	validation_0-mlogloss:0.85610
# [316]	validation_0-mlogloss:0.85592
# [317]	validation_0-mlogloss:0.85604
# [318]	validation_0-mlogloss:0.85600
# [319]	validation_0-mlogloss:0.85618
# [320]	validation_0-mlogloss:0.85598
# [321]	validation_0-mlogloss:0.85602
# [322]	validation_0-mlogloss:0.85615
# [323]	validation_0-mlogloss:0.85588
# [324]	validation_0-mlogloss:0.85590
# [325]	validation_0-mlogloss:0.85587
# [326]	validation_0-mlogloss:0.85587
# [327]	validation_0-mlogloss:0.85597
# [328]	validation_0-mlogloss:0.85605
# [329]	validation_0-mlogloss:0.85610
# [330]	validation_0-mlogloss:0.85615
# [331]	validation_0-mlogloss:0.85602
# [332]	validation_0-mlogloss:0.85625
# [333]	validation_0-mlogloss:0.85636
# [334]	validation_0-mlogloss:0.85641
# [335]	validation_0-mlogloss:0.85617
# [336]	validation_0-mlogloss:0.85617
# [337]	validation_0-mlogloss:0.85616
# [338]	validation_0-mlogloss:0.85623
# [339]	validation_0-mlogloss:0.85620
# [340]	validation_0-mlogloss:0.85629
# [341]	validation_0-mlogloss:0.85611
# [342]	validation_0-mlogloss:0.85609
# [343]	validation_0-mlogloss:0.85620
# [344]	validation_0-mlogloss:0.85613
# [345]	validation_0-mlogloss:0.85599
# [346]	validation_0-mlogloss:0.85590
# [347]	validation_0-mlogloss:0.85591
# [348]	validation_0-mlogloss:0.85590
# [349]	validation_0-mlogloss:0.85593
# [350]	validation_0-mlogloss:0.85603
# [351]	validation_0-mlogloss:0.85629
# [352]	validation_0-mlogloss:0.85627
# [353]	validation_0-mlogloss:0.85617
# [354]	validation_0-mlogloss:0.85609
# [355]	validation_0-mlogloss:0.85613
# [356]	validation_0-mlogloss:0.85622
# [357]	validation_0-mlogloss:0.85615
# [358]	validation_0-mlogloss:0.85613
# [359]	validation_0-mlogloss:0.85610
# [360]	validation_0-mlogloss:0.85633
# [361]	validation_0-mlogloss:0.85626
# [362]	validation_0-mlogloss:0.85616
# [363]	validation_0-mlogloss:0.85588
# [364]	validation_0-mlogloss:0.85577
# [365]	validation_0-mlogloss:0.85564
# [366]	validation_0-mlogloss:0.85581
# [367]	validation_0-mlogloss:0.85573
# [368]	validation_0-mlogloss:0.85566
# [369]	validation_0-mlogloss:0.85577
# [370]	validation_0-mlogloss:0.85569
# [371]	validation_0-mlogloss:0.85559
# [372]	validation_0-mlogloss:0.85546
# [373]	validation_0-mlogloss:0.85554
# [374]	validation_0-mlogloss:0.85564
# [375]	validation_0-mlogloss:0.85556
# [376]	validation_0-mlogloss:0.85543
# [377]	validation_0-mlogloss:0.85523
# [378]	validation_0-mlogloss:0.85505
# [379]	validation_0-mlogloss:0.85517
# [380]	validation_0-mlogloss:0.85531
# [381]	validation_0-mlogloss:0.85536
# [382]	validation_0-mlogloss:0.85544
# [383]	validation_0-mlogloss:0.85549
# [384]	validation_0-mlogloss:0.85556
# [385]	validation_0-mlogloss:0.85554
# [386]	validation_0-mlogloss:0.85568
# [387]	validation_0-mlogloss:0.85588
# [388]	validation_0-mlogloss:0.85583
# [389]	validation_0-mlogloss:0.85574
# [390]	validation_0-mlogloss:0.85583
# [391]	validation_0-mlogloss:0.85585
# [392]	validation_0-mlogloss:0.85588
# [393]	validation_0-mlogloss:0.85589
# [394]	validation_0-mlogloss:0.85602
# [395]	validation_0-mlogloss:0.85604
# [396]	validation_0-mlogloss:0.85609
# [397]	validation_0-mlogloss:0.85602
# [398]	validation_0-mlogloss:0.85599
# [399]	validation_0-mlogloss:0.85578
# [400]	validation_0-mlogloss:0.85589
# [401]	validation_0-mlogloss:0.85580
# [402]	validation_0-mlogloss:0.85599
# [403]	validation_0-mlogloss:0.85578
# [404]	validation_0-mlogloss:0.85569
# [405]	validation_0-mlogloss:0.85554
# [406]	validation_0-mlogloss:0.85559
# [407]	validation_0-mlogloss:0.85575
# [408]	validation_0-mlogloss:0.85568
# [409]	validation_0-mlogloss:0.85569
# [410]	validation_0-mlogloss:0.85585
# [411]	validation_0-mlogloss:0.85588
# [412]	validation_0-mlogloss:0.85589
# [413]	validation_0-mlogloss:0.85592
# [414]	validation_0-mlogloss:0.85598
# [415]	validation_0-mlogloss:0.85606
# [416]	validation_0-mlogloss:0.85599
# [417]	validation_0-mlogloss:0.85604
# [418]	validation_0-mlogloss:0.85602
# [419]	validation_0-mlogloss:0.85596
# [420]	validation_0-mlogloss:0.85601
# [421]	validation_0-mlogloss:0.85625
# [422]	validation_0-mlogloss:0.85613
# [423]	validation_0-mlogloss:0.85613
# [424]	validation_0-mlogloss:0.85612
# [425]	validation_0-mlogloss:0.85616
# [426]	validation_0-mlogloss:0.85589
# [427]	validation_0-mlogloss:0.85582
# [428]	validation_0-mlogloss:0.85576
# [429]	validation_0-mlogloss:0.85591
# [430]	validation_0-mlogloss:0.85612
# [431]	validation_0-mlogloss:0.85620
# [432]	validation_0-mlogloss:0.85621
# [433]	validation_0-mlogloss:0.85621
# [434]	validation_0-mlogloss:0.85634
# [435]	validation_0-mlogloss:0.85658
# [436]	validation_0-mlogloss:0.85660
# [437]	validation_0-mlogloss:0.85656
# [438]	validation_0-mlogloss:0.85651
# [439]	validation_0-mlogloss:0.85652
# [440]	validation_0-mlogloss:0.85650
# [441]	validation_0-mlogloss:0.85654
# [442]	validation_0-mlogloss:0.85647
# [443]	validation_0-mlogloss:0.85665
# [444]	validation_0-mlogloss:0.85673
# [445]	validation_0-mlogloss:0.85689
# [446]	validation_0-mlogloss:0.85707
# [447]	validation_0-mlogloss:0.85717
# [448]	validation_0-mlogloss:0.85727
# [449]	validation_0-mlogloss:0.85729
# [450]	validation_0-mlogloss:0.85730
# [451]	validation_0-mlogloss:0.85717
# [452]	validation_0-mlogloss:0.85739
# [453]	validation_0-mlogloss:0.85756
# [454]	validation_0-mlogloss:0.85744
# [455]	validation_0-mlogloss:0.85740
# [456]	validation_0-mlogloss:0.85730
# [457]	validation_0-mlogloss:0.85735
# [458]	validation_0-mlogloss:0.85736
# [459]	validation_0-mlogloss:0.85739
# [460]	validation_0-mlogloss:0.85736
# [461]	validation_0-mlogloss:0.85719
# [462]	validation_0-mlogloss:0.85733
# [463]	validation_0-mlogloss:0.85730
# [464]	validation_0-mlogloss:0.85723
# [465]	validation_0-mlogloss:0.85727
# [466]	validation_0-mlogloss:0.85748
# [467]	validation_0-mlogloss:0.85756
# [468]	validation_0-mlogloss:0.85756
# [469]	validation_0-mlogloss:0.85755
# [470]	validation_0-mlogloss:0.85753
# [471]	validation_0-mlogloss:0.85761
# [472]	validation_0-mlogloss:0.85775
# [473]	validation_0-mlogloss:0.85777
# [474]	validation_0-mlogloss:0.85784
# [475]	validation_0-mlogloss:0.85776
# [476]	validation_0-mlogloss:0.85796
# [477]	validation_0-mlogloss:0.85801
# [478]	validation_0-mlogloss:0.85803
# [479]	validation_0-mlogloss:0.85799
# [480]	validation_0-mlogloss:0.85780
# [481]	validation_0-mlogloss:0.85785
# [482]	validation_0-mlogloss:0.85798
# [483]	validation_0-mlogloss:0.85801
# [484]	validation_0-mlogloss:0.85791
# [485]	validation_0-mlogloss:0.85796
# [486]	validation_0-mlogloss:0.85791
# [487]	validation_0-mlogloss:0.85782
# [488]	validation_0-mlogloss:0.85790
# [489]	validation_0-mlogloss:0.85779
# [490]	validation_0-mlogloss:0.85781
# [491]	validation_0-mlogloss:0.85767
# [492]	validation_0-mlogloss:0.85770
# [493]	validation_0-mlogloss:0.85768
# [494]	validation_0-mlogloss:0.85784
# [495]	validation_0-mlogloss:0.85794
# [496]	validation_0-mlogloss:0.85796
# [497]	validation_0-mlogloss:0.85808
# [498]	validation_0-mlogloss:0.85821
# [499]	validation_0-mlogloss:0.85815
# [500]	validation_0-mlogloss:0.85819
# [501]	validation_0-mlogloss:0.85812
# [502]	validation_0-mlogloss:0.85814
# [503]	validation_0-mlogloss:0.85820
# [504]	validation_0-mlogloss:0.85832
# [505]	validation_0-mlogloss:0.85827
# [506]	validation_0-mlogloss:0.85834
# [507]	validation_0-mlogloss:0.85845
# [508]	validation_0-mlogloss:0.85845
# [509]	validation_0-mlogloss:0.85860
# [510]	validation_0-mlogloss:0.85854
# [511]	validation_0-mlogloss:0.85840
# [512]	validation_0-mlogloss:0.85856
# [513]	validation_0-mlogloss:0.85857
# [514]	validation_0-mlogloss:0.85847
# [515]	validation_0-mlogloss:0.85843
# [516]	validation_0-mlogloss:0.85855
# [517]	validation_0-mlogloss:0.85857
# [518]	validation_0-mlogloss:0.85857
# [519]	validation_0-mlogloss:0.85857
# [520]	validation_0-mlogloss:0.85862
# [521]	validation_0-mlogloss:0.85856
# [522]	validation_0-mlogloss:0.85854
# [523]	validation_0-mlogloss:0.85851
# [524]	validation_0-mlogloss:0.85849
# [525]	validation_0-mlogloss:0.85849
# [526]	validation_0-mlogloss:0.85846
# [527]	validation_0-mlogloss:0.85855
# [528]	validation_0-mlogloss:0.85844
# [529]	validation_0-mlogloss:0.85839
# [530]	validation_0-mlogloss:0.85832
# [531]	validation_0-mlogloss:0.85851
# [532]	validation_0-mlogloss:0.85854
# [533]	validation_0-mlogloss:0.85861
# [534]	validation_0-mlogloss:0.85862
# [535]	validation_0-mlogloss:0.85860
# [536]	validation_0-mlogloss:0.85870
# [537]	validation_0-mlogloss:0.85886
# [538]	validation_0-mlogloss:0.85898
# [539]	validation_0-mlogloss:0.85892
# [540]	validation_0-mlogloss:0.85882
# [541]	validation_0-mlogloss:0.85878
# [542]	validation_0-mlogloss:0.85880
# [543]	validation_0-mlogloss:0.85877
# [544]	validation_0-mlogloss:0.85873
# [545]	validation_0-mlogloss:0.85886
# [546]	validation_0-mlogloss:0.85896
# [547]	validation_0-mlogloss:0.85890
# [548]	validation_0-mlogloss:0.85879
# [549]	validation_0-mlogloss:0.85870
# [550]	validation_0-mlogloss:0.85877
# [551]	validation_0-mlogloss:0.85883
# [552]	validation_0-mlogloss:0.85881
# [553]	validation_0-mlogloss:0.85902
# [554]	validation_0-mlogloss:0.85907
# [555]	validation_0-mlogloss:0.85885
# [556]	validation_0-mlogloss:0.85891
# [557]	validation_0-mlogloss:0.85900
# [558]	validation_0-mlogloss:0.85910
# [559]	validation_0-mlogloss:0.85904
# [560]	validation_0-mlogloss:0.85910
# [561]	validation_0-mlogloss:0.85911
# [562]	validation_0-mlogloss:0.85923
# [563]	validation_0-mlogloss:0.85927
# [564]	validation_0-mlogloss:0.85936
# [565]	validation_0-mlogloss:0.85937
# [566]	validation_0-mlogloss:0.85945
# [567]	validation_0-mlogloss:0.85941
# [568]	validation_0-mlogloss:0.85940
# [569]	validation_0-mlogloss:0.85943
# [570]	validation_0-mlogloss:0.85933
# [571]	validation_0-mlogloss:0.85928
# [572]	validation_0-mlogloss:0.85928
# [573]	validation_0-mlogloss:0.85923
# [574]	validation_0-mlogloss:0.85921
# [575]	validation_0-mlogloss:0.85913
# [576]	validation_0-mlogloss:0.85920
# [577]	validation_0-mlogloss:0.85923
# [578]	validation_0-mlogloss:0.85917
# [579]	validation_0-mlogloss:0.85932
# [580]	validation_0-mlogloss:0.85930
# [581]	validation_0-mlogloss:0.85927
# [582]	validation_0-mlogloss:0.85940
# [583]	validation_0-mlogloss:0.85938
# [584]	validation_0-mlogloss:0.85929
# [585]	validation_0-mlogloss:0.85940
# [586]	validation_0-mlogloss:0.85942
# [587]	validation_0-mlogloss:0.85942
# [588]	validation_0-mlogloss:0.85931
# [589]	validation_0-mlogloss:0.85941
# [590]	validation_0-mlogloss:0.85938
# [591]	validation_0-mlogloss:0.85945
# [592]	validation_0-mlogloss:0.85931
# [593]	validation_0-mlogloss:0.85938
# [594]	validation_0-mlogloss:0.85947
# [595]	validation_0-mlogloss:0.85946
# [596]	validation_0-mlogloss:0.85953
# [597]	validation_0-mlogloss:0.85974
# [598]	validation_0-mlogloss:0.85981
# [599]	validation_0-mlogloss:0.85983
# Fold 1: Accuracy=0.6971, Macro-F1=0.6944
# [0]	validation_0-mlogloss:2.62004
# [1]	validation_0-mlogloss:2.43974
# [2]	validation_0-mlogloss:2.30083
# [3]	validation_0-mlogloss:2.18943
# [4]	validation_0-mlogloss:2.09370
# [5]	validation_0-mlogloss:2.00859
# [6]	validation_0-mlogloss:1.93330
# [7]	validation_0-mlogloss:1.86678
# [8]	validation_0-mlogloss:1.80736
# [9]	validation_0-mlogloss:1.75373
# [10]	validation_0-mlogloss:1.70629
# [11]	validation_0-mlogloss:1.66132
# [12]	validation_0-mlogloss:1.62151
# [13]	validation_0-mlogloss:1.58431
# [14]	validation_0-mlogloss:1.54912
# [15]	validation_0-mlogloss:1.51659
# [16]	validation_0-mlogloss:1.48345
# [17]	validation_0-mlogloss:1.45354
# [18]	validation_0-mlogloss:1.42621
# [19]	validation_0-mlogloss:1.39945
# [20]	validation_0-mlogloss:1.37534
# [21]	validation_0-mlogloss:1.35183
# [22]	validation_0-mlogloss:1.32946
# [23]	validation_0-mlogloss:1.30796
# [24]	validation_0-mlogloss:1.29044
# [25]	validation_0-mlogloss:1.27200
# [26]	validation_0-mlogloss:1.25458
# [27]	validation_0-mlogloss:1.23765
# [28]	validation_0-mlogloss:1.22149
# [29]	validation_0-mlogloss:1.20738
# [30]	validation_0-mlogloss:1.19386
# [31]	validation_0-mlogloss:1.18130
# [32]	validation_0-mlogloss:1.16889
# [33]	validation_0-mlogloss:1.15747
# [34]	validation_0-mlogloss:1.14655
# [35]	validation_0-mlogloss:1.13592
# [36]	validation_0-mlogloss:1.12615
# [37]	validation_0-mlogloss:1.11574
# [38]	validation_0-mlogloss:1.10643
# [39]	validation_0-mlogloss:1.09673
# [40]	validation_0-mlogloss:1.08846
# [41]	validation_0-mlogloss:1.08037
# [42]	validation_0-mlogloss:1.07209
# [43]	validation_0-mlogloss:1.06482
# [44]	validation_0-mlogloss:1.05817
# [45]	validation_0-mlogloss:1.05075
# [46]	validation_0-mlogloss:1.04444
# [47]	validation_0-mlogloss:1.03754
# [48]	validation_0-mlogloss:1.03095
# [49]	validation_0-mlogloss:1.02573
# [50]	validation_0-mlogloss:1.01893
# [51]	validation_0-mlogloss:1.01399
# [52]	validation_0-mlogloss:1.00847
# [53]	validation_0-mlogloss:1.00255
# [54]	validation_0-mlogloss:0.99808
# [55]	validation_0-mlogloss:0.99206
# [56]	validation_0-mlogloss:0.98761
# [57]	validation_0-mlogloss:0.98280
# [58]	validation_0-mlogloss:0.97804
# [59]	validation_0-mlogloss:0.97403
# [60]	validation_0-mlogloss:0.97046
# [61]	validation_0-mlogloss:0.96751
# [62]	validation_0-mlogloss:0.96376
# [63]	validation_0-mlogloss:0.95970
# [64]	validation_0-mlogloss:0.95616
# [65]	validation_0-mlogloss:0.95262
# [66]	validation_0-mlogloss:0.94951
# [67]	validation_0-mlogloss:0.94585
# [68]	validation_0-mlogloss:0.94305
# [69]	validation_0-mlogloss:0.93987
# [70]	validation_0-mlogloss:0.93775
# [71]	validation_0-mlogloss:0.93493
# [72]	validation_0-mlogloss:0.93307
# [73]	validation_0-mlogloss:0.93073
# [74]	validation_0-mlogloss:0.92816
# [75]	validation_0-mlogloss:0.92611
# [76]	validation_0-mlogloss:0.92390
# [77]	validation_0-mlogloss:0.92169
# [78]	validation_0-mlogloss:0.91904
# [79]	validation_0-mlogloss:0.91714
# [80]	validation_0-mlogloss:0.91497
# [81]	validation_0-mlogloss:0.91301
# [82]	validation_0-mlogloss:0.91048
# [83]	validation_0-mlogloss:0.90805
# [84]	validation_0-mlogloss:0.90749
# [85]	validation_0-mlogloss:0.90597
# [86]	validation_0-mlogloss:0.90390
# [87]	validation_0-mlogloss:0.90277
# [88]	validation_0-mlogloss:0.90030
# [89]	validation_0-mlogloss:0.89858
# [90]	validation_0-mlogloss:0.89684
# [91]	validation_0-mlogloss:0.89480
# [92]	validation_0-mlogloss:0.89343
# [93]	validation_0-mlogloss:0.89178
# [94]	validation_0-mlogloss:0.88993
# [95]	validation_0-mlogloss:0.88916
# [96]	validation_0-mlogloss:0.88797
# [97]	validation_0-mlogloss:0.88732
# [98]	validation_0-mlogloss:0.88642
# [99]	validation_0-mlogloss:0.88515
# [100]	validation_0-mlogloss:0.88424
# [101]	validation_0-mlogloss:0.88319
# [102]	validation_0-mlogloss:0.88130
# [103]	validation_0-mlogloss:0.88001
# [104]	validation_0-mlogloss:0.87875
# [105]	validation_0-mlogloss:0.87784
# [106]	validation_0-mlogloss:0.87650
# [107]	validation_0-mlogloss:0.87550
# [108]	validation_0-mlogloss:0.87473
# [109]	validation_0-mlogloss:0.87333
# [110]	validation_0-mlogloss:0.87230
# [111]	validation_0-mlogloss:0.87139
# [112]	validation_0-mlogloss:0.87043
# [113]	validation_0-mlogloss:0.86974
# [114]	validation_0-mlogloss:0.86863
# [115]	validation_0-mlogloss:0.86740
# [116]	validation_0-mlogloss:0.86646
# [117]	validation_0-mlogloss:0.86578
# [118]	validation_0-mlogloss:0.86479
# [119]	validation_0-mlogloss:0.86478
# [120]	validation_0-mlogloss:0.86405
# [121]	validation_0-mlogloss:0.86294
# [122]	validation_0-mlogloss:0.86279
# [123]	validation_0-mlogloss:0.86223
# [124]	validation_0-mlogloss:0.86177
# [125]	validation_0-mlogloss:0.86059
# [126]	validation_0-mlogloss:0.86010
# [127]	validation_0-mlogloss:0.85947
# [128]	validation_0-mlogloss:0.85846
# [129]	validation_0-mlogloss:0.85757
# [130]	validation_0-mlogloss:0.85705
# [131]	validation_0-mlogloss:0.85644
# [132]	validation_0-mlogloss:0.85598
# [133]	validation_0-mlogloss:0.85573
# [134]	validation_0-mlogloss:0.85460
# [135]	validation_0-mlogloss:0.85454
# [136]	validation_0-mlogloss:0.85426
# [137]	validation_0-mlogloss:0.85385
# [138]	validation_0-mlogloss:0.85363
# [139]	validation_0-mlogloss:0.85318
# [140]	validation_0-mlogloss:0.85266
# [141]	validation_0-mlogloss:0.85173
# [142]	validation_0-mlogloss:0.85142
# [143]	validation_0-mlogloss:0.85126
# [144]	validation_0-mlogloss:0.85095
# [145]	validation_0-mlogloss:0.85071
# [146]	validation_0-mlogloss:0.85058
# [147]	validation_0-mlogloss:0.85050
# [148]	validation_0-mlogloss:0.85002
# [149]	validation_0-mlogloss:0.84941
# [150]	validation_0-mlogloss:0.84923
# [151]	validation_0-mlogloss:0.84867
# [152]	validation_0-mlogloss:0.84833
# [153]	validation_0-mlogloss:0.84788
# [154]	validation_0-mlogloss:0.84770
# [155]	validation_0-mlogloss:0.84733
# [156]	validation_0-mlogloss:0.84688
# [157]	validation_0-mlogloss:0.84620
# [158]	validation_0-mlogloss:0.84637
# [159]	validation_0-mlogloss:0.84594
# [160]	validation_0-mlogloss:0.84580
# [161]	validation_0-mlogloss:0.84552
# [162]	validation_0-mlogloss:0.84566
# [163]	validation_0-mlogloss:0.84546
# [164]	validation_0-mlogloss:0.84512
# [165]	validation_0-mlogloss:0.84493
# [166]	validation_0-mlogloss:0.84497
# [167]	validation_0-mlogloss:0.84441
# [168]	validation_0-mlogloss:0.84385
# [169]	validation_0-mlogloss:0.84387
# [170]	validation_0-mlogloss:0.84346
# [171]	validation_0-mlogloss:0.84314
# [172]	validation_0-mlogloss:0.84281
# [173]	validation_0-mlogloss:0.84274
# [174]	validation_0-mlogloss:0.84258
# [175]	validation_0-mlogloss:0.84224
# [176]	validation_0-mlogloss:0.84176
# [177]	validation_0-mlogloss:0.84137
# [178]	validation_0-mlogloss:0.84104
# [179]	validation_0-mlogloss:0.84097
# [180]	validation_0-mlogloss:0.84079
# [181]	validation_0-mlogloss:0.84051
# [182]	validation_0-mlogloss:0.84058
# [183]	validation_0-mlogloss:0.84007
# [184]	validation_0-mlogloss:0.84019
# [185]	validation_0-mlogloss:0.83989
# [186]	validation_0-mlogloss:0.84005
# [187]	validation_0-mlogloss:0.83963
# [188]	validation_0-mlogloss:0.83975
# [189]	validation_0-mlogloss:0.83986
# [190]	validation_0-mlogloss:0.83918
# [191]	validation_0-mlogloss:0.83912
# [192]	validation_0-mlogloss:0.83902
# [193]	validation_0-mlogloss:0.83885
# [194]	validation_0-mlogloss:0.83883
# [195]	validation_0-mlogloss:0.83880
# [196]	validation_0-mlogloss:0.83850
# [197]	validation_0-mlogloss:0.83844
# [198]	validation_0-mlogloss:0.83835
# [199]	validation_0-mlogloss:0.83817
# [200]	validation_0-mlogloss:0.83810
# [201]	validation_0-mlogloss:0.83803
# [202]	validation_0-mlogloss:0.83810
# [203]	validation_0-mlogloss:0.83780
# [204]	validation_0-mlogloss:0.83796
# [205]	validation_0-mlogloss:0.83788
# [206]	validation_0-mlogloss:0.83765
# [207]	validation_0-mlogloss:0.83729
# [208]	validation_0-mlogloss:0.83701
# [209]	validation_0-mlogloss:0.83714
# [210]	validation_0-mlogloss:0.83681
# [211]	validation_0-mlogloss:0.83662
# [212]	validation_0-mlogloss:0.83634
# [213]	validation_0-mlogloss:0.83625
# [214]	validation_0-mlogloss:0.83635
# [215]	validation_0-mlogloss:0.83601
# [216]	validation_0-mlogloss:0.83575
# [217]	validation_0-mlogloss:0.83562
# [218]	validation_0-mlogloss:0.83541
# [219]	validation_0-mlogloss:0.83549
# [220]	validation_0-mlogloss:0.83532
# [221]	validation_0-mlogloss:0.83546
# [222]	validation_0-mlogloss:0.83517
# [223]	validation_0-mlogloss:0.83536
# [224]	validation_0-mlogloss:0.83492
# [225]	validation_0-mlogloss:0.83461
# [226]	validation_0-mlogloss:0.83474
# [227]	validation_0-mlogloss:0.83465
# [228]	validation_0-mlogloss:0.83473
# [229]	validation_0-mlogloss:0.83492
# [230]	validation_0-mlogloss:0.83475
# [231]	validation_0-mlogloss:0.83473
# [232]	validation_0-mlogloss:0.83457
# [233]	validation_0-mlogloss:0.83422
# [234]	validation_0-mlogloss:0.83404
# [235]	validation_0-mlogloss:0.83393
# [236]	validation_0-mlogloss:0.83387
# [237]	validation_0-mlogloss:0.83355
# [238]	validation_0-mlogloss:0.83353
# [239]	validation_0-mlogloss:0.83356
# [240]	validation_0-mlogloss:0.83350
# [241]	validation_0-mlogloss:0.83342
# [242]	validation_0-mlogloss:0.83325
# [243]	validation_0-mlogloss:0.83326
# [244]	validation_0-mlogloss:0.83338
# [245]	validation_0-mlogloss:0.83330
# [246]	validation_0-mlogloss:0.83290
# [247]	validation_0-mlogloss:0.83288
# [248]	validation_0-mlogloss:0.83257
# [249]	validation_0-mlogloss:0.83249
# [250]	validation_0-mlogloss:0.83262
# [251]	validation_0-mlogloss:0.83247
# [252]	validation_0-mlogloss:0.83233
# [253]	validation_0-mlogloss:0.83227
# [254]	validation_0-mlogloss:0.83219
# [255]	validation_0-mlogloss:0.83219
# [256]	validation_0-mlogloss:0.83229
# [257]	validation_0-mlogloss:0.83213
# [258]	validation_0-mlogloss:0.83213
# [259]	validation_0-mlogloss:0.83213
# [260]	validation_0-mlogloss:0.83238
# [261]	validation_0-mlogloss:0.83258
# [262]	validation_0-mlogloss:0.83229
# [263]	validation_0-mlogloss:0.83203
# [264]	validation_0-mlogloss:0.83203
# [265]	validation_0-mlogloss:0.83216
# [266]	validation_0-mlogloss:0.83219
# [267]	validation_0-mlogloss:0.83220
# [268]	validation_0-mlogloss:0.83218
# [269]	validation_0-mlogloss:0.83235
# [270]	validation_0-mlogloss:0.83243
# [271]	validation_0-mlogloss:0.83228
# [272]	validation_0-mlogloss:0.83196
# [273]	validation_0-mlogloss:0.83192
# [274]	validation_0-mlogloss:0.83205
# [275]	validation_0-mlogloss:0.83222
# [276]	validation_0-mlogloss:0.83200
# [277]	validation_0-mlogloss:0.83179
# [278]	validation_0-mlogloss:0.83201
# [279]	validation_0-mlogloss:0.83199
# [280]	validation_0-mlogloss:0.83204
# [281]	validation_0-mlogloss:0.83191
# [282]	validation_0-mlogloss:0.83189
# [283]	validation_0-mlogloss:0.83206
# [284]	validation_0-mlogloss:0.83195
# [285]	validation_0-mlogloss:0.83188
# [286]	validation_0-mlogloss:0.83187
# [287]	validation_0-mlogloss:0.83204
# [288]	validation_0-mlogloss:0.83193
# [289]	validation_0-mlogloss:0.83204
# [290]	validation_0-mlogloss:0.83213
# [291]	validation_0-mlogloss:0.83203
# [292]	validation_0-mlogloss:0.83174
# [293]	validation_0-mlogloss:0.83175
# [294]	validation_0-mlogloss:0.83166
# [295]	validation_0-mlogloss:0.83180
# [296]	validation_0-mlogloss:0.83186
# [297]	validation_0-mlogloss:0.83178
# [298]	validation_0-mlogloss:0.83196
# [299]	validation_0-mlogloss:0.83185
# [300]	validation_0-mlogloss:0.83208
# [301]	validation_0-mlogloss:0.83209
# [302]	validation_0-mlogloss:0.83203
# [303]	validation_0-mlogloss:0.83218
# [304]	validation_0-mlogloss:0.83226
# [305]	validation_0-mlogloss:0.83219
# [306]	validation_0-mlogloss:0.83227
# [307]	validation_0-mlogloss:0.83210
# [308]	validation_0-mlogloss:0.83202
# [309]	validation_0-mlogloss:0.83182
# [310]	validation_0-mlogloss:0.83202
# [311]	validation_0-mlogloss:0.83187
# [312]	validation_0-mlogloss:0.83210
# [313]	validation_0-mlogloss:0.83204
# [314]	validation_0-mlogloss:0.83181
# [315]	validation_0-mlogloss:0.83192
# [316]	validation_0-mlogloss:0.83179
# [317]	validation_0-mlogloss:0.83188
# [318]	validation_0-mlogloss:0.83211
# [319]	validation_0-mlogloss:0.83208
# [320]	validation_0-mlogloss:0.83209
# [321]	validation_0-mlogloss:0.83207
# [322]	validation_0-mlogloss:0.83217
# [323]	validation_0-mlogloss:0.83206
# [324]	validation_0-mlogloss:0.83211
# [325]	validation_0-mlogloss:0.83204
# [326]	validation_0-mlogloss:0.83197
# [327]	validation_0-mlogloss:0.83199
# [328]	validation_0-mlogloss:0.83197
# [329]	validation_0-mlogloss:0.83187
# [330]	validation_0-mlogloss:0.83184
# [331]	validation_0-mlogloss:0.83192
# [332]	validation_0-mlogloss:0.83194
# [333]	validation_0-mlogloss:0.83191
# [334]	validation_0-mlogloss:0.83197
# [335]	validation_0-mlogloss:0.83194
# [336]	validation_0-mlogloss:0.83208
# [337]	validation_0-mlogloss:0.83187
# [338]	validation_0-mlogloss:0.83191
# [339]	validation_0-mlogloss:0.83197
# [340]	validation_0-mlogloss:0.83208
# [341]	validation_0-mlogloss:0.83226
# [342]	validation_0-mlogloss:0.83230
# [343]	validation_0-mlogloss:0.83229
# [344]	validation_0-mlogloss:0.83245
# [345]	validation_0-mlogloss:0.83241
# [346]	validation_0-mlogloss:0.83250
# [347]	validation_0-mlogloss:0.83244
# [348]	validation_0-mlogloss:0.83263
# [349]	validation_0-mlogloss:0.83257
# [350]	validation_0-mlogloss:0.83263
# [351]	validation_0-mlogloss:0.83230
# [352]	validation_0-mlogloss:0.83206
# [353]	validation_0-mlogloss:0.83214
# [354]	validation_0-mlogloss:0.83212
# [355]	validation_0-mlogloss:0.83212
# [356]	validation_0-mlogloss:0.83208
# [357]	validation_0-mlogloss:0.83180
# [358]	validation_0-mlogloss:0.83157
# [359]	validation_0-mlogloss:0.83159
# [360]	validation_0-mlogloss:0.83160
# [361]	validation_0-mlogloss:0.83147
# [362]	validation_0-mlogloss:0.83147
# [363]	validation_0-mlogloss:0.83132
# [364]	validation_0-mlogloss:0.83129
# [365]	validation_0-mlogloss:0.83145
# [366]	validation_0-mlogloss:0.83158
# [367]	validation_0-mlogloss:0.83169
# [368]	validation_0-mlogloss:0.83166
# [369]	validation_0-mlogloss:0.83171
# [370]	validation_0-mlogloss:0.83166
# [371]	validation_0-mlogloss:0.83160
# [372]	validation_0-mlogloss:0.83148
# [373]	validation_0-mlogloss:0.83150
# [374]	validation_0-mlogloss:0.83142
# [375]	validation_0-mlogloss:0.83140
# [376]	validation_0-mlogloss:0.83125
# [377]	validation_0-mlogloss:0.83142
# [378]	validation_0-mlogloss:0.83148
# [379]	validation_0-mlogloss:0.83145
# [380]	validation_0-mlogloss:0.83142
# [381]	validation_0-mlogloss:0.83154
# [382]	validation_0-mlogloss:0.83177
# [383]	validation_0-mlogloss:0.83178
# [384]	validation_0-mlogloss:0.83175
# [385]	validation_0-mlogloss:0.83170
# [386]	validation_0-mlogloss:0.83161
# [387]	validation_0-mlogloss:0.83182
# [388]	validation_0-mlogloss:0.83169
# [389]	validation_0-mlogloss:0.83159
# [390]	validation_0-mlogloss:0.83153
# [391]	validation_0-mlogloss:0.83151
# [392]	validation_0-mlogloss:0.83169
# [393]	validation_0-mlogloss:0.83177
# [394]	validation_0-mlogloss:0.83174
# [395]	validation_0-mlogloss:0.83183
# [396]	validation_0-mlogloss:0.83185
# [397]	validation_0-mlogloss:0.83185
# [398]	validation_0-mlogloss:0.83178
# [399]	validation_0-mlogloss:0.83152
# [400]	validation_0-mlogloss:0.83139
# [401]	validation_0-mlogloss:0.83128
# [402]	validation_0-mlogloss:0.83130
# [403]	validation_0-mlogloss:0.83104
# [404]	validation_0-mlogloss:0.83124
# [405]	validation_0-mlogloss:0.83138
# [406]	validation_0-mlogloss:0.83138
# [407]	validation_0-mlogloss:0.83152
# [408]	validation_0-mlogloss:0.83162
# [409]	validation_0-mlogloss:0.83163
# [410]	validation_0-mlogloss:0.83173
# [411]	validation_0-mlogloss:0.83185
# [412]	validation_0-mlogloss:0.83170
# [413]	validation_0-mlogloss:0.83170
# [414]	validation_0-mlogloss:0.83166
# [415]	validation_0-mlogloss:0.83164
# [416]	validation_0-mlogloss:0.83164
# [417]	validation_0-mlogloss:0.83168
# [418]	validation_0-mlogloss:0.83169
# [419]	validation_0-mlogloss:0.83155
# [420]	validation_0-mlogloss:0.83147
# [421]	validation_0-mlogloss:0.83140
# [422]	validation_0-mlogloss:0.83136
# [423]	validation_0-mlogloss:0.83123
# [424]	validation_0-mlogloss:0.83121
# [425]	validation_0-mlogloss:0.83118
# [426]	validation_0-mlogloss:0.83109
# [427]	validation_0-mlogloss:0.83116
# [428]	validation_0-mlogloss:0.83118
# [429]	validation_0-mlogloss:0.83116
# [430]	validation_0-mlogloss:0.83117
# [431]	validation_0-mlogloss:0.83123
# [432]	validation_0-mlogloss:0.83147
# [433]	validation_0-mlogloss:0.83144
# [434]	validation_0-mlogloss:0.83150
# [435]	validation_0-mlogloss:0.83154
# [436]	validation_0-mlogloss:0.83142
# [437]	validation_0-mlogloss:0.83141
# [438]	validation_0-mlogloss:0.83129
# [439]	validation_0-mlogloss:0.83124
# [440]	validation_0-mlogloss:0.83136
# [441]	validation_0-mlogloss:0.83141
# [442]	validation_0-mlogloss:0.83138
# [443]	validation_0-mlogloss:0.83130
# [444]	validation_0-mlogloss:0.83151
# [445]	validation_0-mlogloss:0.83149
# [446]	validation_0-mlogloss:0.83162
# [447]	validation_0-mlogloss:0.83175
# [448]	validation_0-mlogloss:0.83164
# [449]	validation_0-mlogloss:0.83161
# [450]	validation_0-mlogloss:0.83158
# [451]	validation_0-mlogloss:0.83159
# [452]	validation_0-mlogloss:0.83158
# [453]	validation_0-mlogloss:0.83170
# [454]	validation_0-mlogloss:0.83161
# [455]	validation_0-mlogloss:0.83162
# [456]	validation_0-mlogloss:0.83165
# [457]	validation_0-mlogloss:0.83170
# [458]	validation_0-mlogloss:0.83169
# [459]	validation_0-mlogloss:0.83176
# [460]	validation_0-mlogloss:0.83168
# [461]	validation_0-mlogloss:0.83171
# [462]	validation_0-mlogloss:0.83159
# [463]	validation_0-mlogloss:0.83177
# [464]	validation_0-mlogloss:0.83173
# [465]	validation_0-mlogloss:0.83177
# [466]	validation_0-mlogloss:0.83186
# [467]	validation_0-mlogloss:0.83181
# [468]	validation_0-mlogloss:0.83178
# [469]	validation_0-mlogloss:0.83172
# [470]	validation_0-mlogloss:0.83186
# [471]	validation_0-mlogloss:0.83190
# [472]	validation_0-mlogloss:0.83205
# [473]	validation_0-mlogloss:0.83215
# [474]	validation_0-mlogloss:0.83216
# [475]	validation_0-mlogloss:0.83202
# [476]	validation_0-mlogloss:0.83184
# [477]	validation_0-mlogloss:0.83189
# [478]	validation_0-mlogloss:0.83202
# [479]	validation_0-mlogloss:0.83203
# [480]	validation_0-mlogloss:0.83205
# [481]	validation_0-mlogloss:0.83187
# [482]	validation_0-mlogloss:0.83187
# [483]	validation_0-mlogloss:0.83199
# [484]	validation_0-mlogloss:0.83198
# [485]	validation_0-mlogloss:0.83206
# [486]	validation_0-mlogloss:0.83203
# [487]	validation_0-mlogloss:0.83213
# [488]	validation_0-mlogloss:0.83201
# [489]	validation_0-mlogloss:0.83193
# [490]	validation_0-mlogloss:0.83197
# [491]	validation_0-mlogloss:0.83203
# [492]	validation_0-mlogloss:0.83201
# [493]	validation_0-mlogloss:0.83198
# [494]	validation_0-mlogloss:0.83199
# [495]	validation_0-mlogloss:0.83209
# [496]	validation_0-mlogloss:0.83217
# [497]	validation_0-mlogloss:0.83215
# [498]	validation_0-mlogloss:0.83207
# [499]	validation_0-mlogloss:0.83216
# [500]	validation_0-mlogloss:0.83220
# [501]	validation_0-mlogloss:0.83218
# [502]	validation_0-mlogloss:0.83218
# [503]	validation_0-mlogloss:0.83222
# [504]	validation_0-mlogloss:0.83236
# [505]	validation_0-mlogloss:0.83235
# [506]	validation_0-mlogloss:0.83232
# [507]	validation_0-mlogloss:0.83225
# [508]	validation_0-mlogloss:0.83245
# [509]	validation_0-mlogloss:0.83247
# [510]	validation_0-mlogloss:0.83264
# [511]	validation_0-mlogloss:0.83280
# [512]	validation_0-mlogloss:0.83276
# [513]	validation_0-mlogloss:0.83273
# [514]	validation_0-mlogloss:0.83272
# [515]	validation_0-mlogloss:0.83275
# [516]	validation_0-mlogloss:0.83270
# [517]	validation_0-mlogloss:0.83277
# [518]	validation_0-mlogloss:0.83284
# [519]	validation_0-mlogloss:0.83285
# [520]	validation_0-mlogloss:0.83269
# [521]	validation_0-mlogloss:0.83278
# [522]	validation_0-mlogloss:0.83280
# [523]	validation_0-mlogloss:0.83276
# [524]	validation_0-mlogloss:0.83265
# [525]	validation_0-mlogloss:0.83276
# [526]	validation_0-mlogloss:0.83268
# [527]	validation_0-mlogloss:0.83277
# [528]	validation_0-mlogloss:0.83278
# [529]	validation_0-mlogloss:0.83274
# [530]	validation_0-mlogloss:0.83287
# [531]	validation_0-mlogloss:0.83300
# [532]	validation_0-mlogloss:0.83296
# [533]	validation_0-mlogloss:0.83304
# [534]	validation_0-mlogloss:0.83293
# [535]	validation_0-mlogloss:0.83301
# [536]	validation_0-mlogloss:0.83306
# [537]	validation_0-mlogloss:0.83309
# [538]	validation_0-mlogloss:0.83301
# [539]	validation_0-mlogloss:0.83296
# [540]	validation_0-mlogloss:0.83303
# [541]	validation_0-mlogloss:0.83317
# [542]	validation_0-mlogloss:0.83324
# [543]	validation_0-mlogloss:0.83322
# [544]	validation_0-mlogloss:0.83331
# [545]	validation_0-mlogloss:0.83327
# [546]	validation_0-mlogloss:0.83322
# [547]	validation_0-mlogloss:0.83328
# [548]	validation_0-mlogloss:0.83326
# [549]	validation_0-mlogloss:0.83323
# [550]	validation_0-mlogloss:0.83329
# [551]	validation_0-mlogloss:0.83336
# [552]	validation_0-mlogloss:0.83337
# [553]	validation_0-mlogloss:0.83343
# [554]	validation_0-mlogloss:0.83334
# [555]	validation_0-mlogloss:0.83336
# [556]	validation_0-mlogloss:0.83328
# [557]	validation_0-mlogloss:0.83322
# [558]	validation_0-mlogloss:0.83325
# [559]	validation_0-mlogloss:0.83325
# [560]	validation_0-mlogloss:0.83328
# [561]	validation_0-mlogloss:0.83335
# [562]	validation_0-mlogloss:0.83338
# [563]	validation_0-mlogloss:0.83337
# [564]	validation_0-mlogloss:0.83327
# [565]	validation_0-mlogloss:0.83339
# [566]	validation_0-mlogloss:0.83337
# [567]	validation_0-mlogloss:0.83333
# [568]	validation_0-mlogloss:0.83338
# [569]	validation_0-mlogloss:0.83337
# [570]	validation_0-mlogloss:0.83350
# [571]	validation_0-mlogloss:0.83348
# [572]	validation_0-mlogloss:0.83343
# [573]	validation_0-mlogloss:0.83334
# [574]	validation_0-mlogloss:0.83332
# [575]	validation_0-mlogloss:0.83347
# [576]	validation_0-mlogloss:0.83360
# [577]	validation_0-mlogloss:0.83350
# [578]	validation_0-mlogloss:0.83349
# [579]	validation_0-mlogloss:0.83354
# [580]	validation_0-mlogloss:0.83358
# [581]	validation_0-mlogloss:0.83356
# [582]	validation_0-mlogloss:0.83364
# [583]	validation_0-mlogloss:0.83365
# [584]	validation_0-mlogloss:0.83361
# [585]	validation_0-mlogloss:0.83354
# [586]	validation_0-mlogloss:0.83355
# [587]	validation_0-mlogloss:0.83342
# [588]	validation_0-mlogloss:0.83354
# [589]	validation_0-mlogloss:0.83360
# [590]	validation_0-mlogloss:0.83375
# [591]	validation_0-mlogloss:0.83383
# [592]	validation_0-mlogloss:0.83377
# [593]	validation_0-mlogloss:0.83379
# [594]	validation_0-mlogloss:0.83390
# [595]	validation_0-mlogloss:0.83406
# [596]	validation_0-mlogloss:0.83394
# [597]	validation_0-mlogloss:0.83407
# [598]	validation_0-mlogloss:0.83414
# [599]	validation_0-mlogloss:0.83416
# Fold 2: Accuracy=0.7018, Macro-F1=0.6969
# [0]	validation_0-mlogloss:2.60966
# [1]	validation_0-mlogloss:2.43493
# [2]	validation_0-mlogloss:2.29547
# [3]	validation_0-mlogloss:2.18826
# [4]	validation_0-mlogloss:2.09368
# [5]	validation_0-mlogloss:2.01226
# [6]	validation_0-mlogloss:1.94084
# [7]	validation_0-mlogloss:1.87781
# [8]	validation_0-mlogloss:1.81994
# [9]	validation_0-mlogloss:1.76767
# [10]	validation_0-mlogloss:1.72270
# [11]	validation_0-mlogloss:1.68028
# [12]	validation_0-mlogloss:1.64130
# [13]	validation_0-mlogloss:1.60516
# [14]	validation_0-mlogloss:1.57240
# [15]	validation_0-mlogloss:1.54013
# [16]	validation_0-mlogloss:1.51037
# [17]	validation_0-mlogloss:1.48367
# [18]	validation_0-mlogloss:1.45832
# [19]	validation_0-mlogloss:1.43342
# [20]	validation_0-mlogloss:1.40973
# [21]	validation_0-mlogloss:1.38931
# [22]	validation_0-mlogloss:1.36821
# [23]	validation_0-mlogloss:1.34705
# [24]	validation_0-mlogloss:1.32872
# [25]	validation_0-mlogloss:1.31257
# [26]	validation_0-mlogloss:1.29635
# [27]	validation_0-mlogloss:1.27983
# [28]	validation_0-mlogloss:1.26640
# [29]	validation_0-mlogloss:1.25280
# [30]	validation_0-mlogloss:1.24044
# [31]	validation_0-mlogloss:1.22828
# [32]	validation_0-mlogloss:1.21575
# [33]	validation_0-mlogloss:1.20282
# [34]	validation_0-mlogloss:1.19255
# [35]	validation_0-mlogloss:1.18187
# [36]	validation_0-mlogloss:1.17212
# [37]	validation_0-mlogloss:1.16176
# [38]	validation_0-mlogloss:1.15382
# [39]	validation_0-mlogloss:1.14545
# [40]	validation_0-mlogloss:1.13720
# [41]	validation_0-mlogloss:1.12980
# [42]	validation_0-mlogloss:1.12163
# [43]	validation_0-mlogloss:1.11451
# [44]	validation_0-mlogloss:1.10663
# [45]	validation_0-mlogloss:1.09957
# [46]	validation_0-mlogloss:1.09251
# [47]	validation_0-mlogloss:1.08671
# [48]	validation_0-mlogloss:1.07992
# [49]	validation_0-mlogloss:1.07496
# [50]	validation_0-mlogloss:1.06948
# [51]	validation_0-mlogloss:1.06458
# [52]	validation_0-mlogloss:1.05902
# [53]	validation_0-mlogloss:1.05350
# [54]	validation_0-mlogloss:1.04893
# [55]	validation_0-mlogloss:1.04432
# [56]	validation_0-mlogloss:1.03906
# [57]	validation_0-mlogloss:1.03450
# [58]	validation_0-mlogloss:1.03078
# [59]	validation_0-mlogloss:1.02665
# [60]	validation_0-mlogloss:1.02269
# [61]	validation_0-mlogloss:1.01913
# [62]	validation_0-mlogloss:1.01514
# [63]	validation_0-mlogloss:1.01183
# [64]	validation_0-mlogloss:1.00798
# [65]	validation_0-mlogloss:1.00413
# [66]	validation_0-mlogloss:1.00074
# [67]	validation_0-mlogloss:0.99772
# [68]	validation_0-mlogloss:0.99515
# [69]	validation_0-mlogloss:0.99228
# [70]	validation_0-mlogloss:0.99003
# [71]	validation_0-mlogloss:0.98713
# [72]	validation_0-mlogloss:0.98496
# [73]	validation_0-mlogloss:0.98225
# [74]	validation_0-mlogloss:0.97978
# [75]	validation_0-mlogloss:0.97660
# [76]	validation_0-mlogloss:0.97414
# [77]	validation_0-mlogloss:0.97136
# [78]	validation_0-mlogloss:0.96873
# [79]	validation_0-mlogloss:0.96641
# [80]	validation_0-mlogloss:0.96429
# [81]	validation_0-mlogloss:0.96250
# [82]	validation_0-mlogloss:0.96070
# [83]	validation_0-mlogloss:0.95840
# [84]	validation_0-mlogloss:0.95649
# [85]	validation_0-mlogloss:0.95542
# [86]	validation_0-mlogloss:0.95431
# [87]	validation_0-mlogloss:0.95246
# [88]	validation_0-mlogloss:0.95108
# [89]	validation_0-mlogloss:0.94900
# [90]	validation_0-mlogloss:0.94697
# [91]	validation_0-mlogloss:0.94531
# [92]	validation_0-mlogloss:0.94455
# [93]	validation_0-mlogloss:0.94335
# [94]	validation_0-mlogloss:0.94216
# [95]	validation_0-mlogloss:0.94080
# [96]	validation_0-mlogloss:0.94022
# [97]	validation_0-mlogloss:0.93938
# [98]	validation_0-mlogloss:0.93817
# [99]	validation_0-mlogloss:0.93670
# [100]	validation_0-mlogloss:0.93564
# [101]	validation_0-mlogloss:0.93496
# [102]	validation_0-mlogloss:0.93461
# [103]	validation_0-mlogloss:0.93363
# [104]	validation_0-mlogloss:0.93220
# [105]	validation_0-mlogloss:0.93128
# [106]	validation_0-mlogloss:0.93044
# [107]	validation_0-mlogloss:0.92959
# [108]	validation_0-mlogloss:0.92882
# [109]	validation_0-mlogloss:0.92744
# [110]	validation_0-mlogloss:0.92673
# [111]	validation_0-mlogloss:0.92529
# [112]	validation_0-mlogloss:0.92495
# [113]	validation_0-mlogloss:0.92397
# [114]	validation_0-mlogloss:0.92393
# [115]	validation_0-mlogloss:0.92319
# [116]	validation_0-mlogloss:0.92254
# [117]	validation_0-mlogloss:0.92236
# [118]	validation_0-mlogloss:0.92204
# [119]	validation_0-mlogloss:0.92124
# [120]	validation_0-mlogloss:0.92074
# [121]	validation_0-mlogloss:0.92071
# [122]	validation_0-mlogloss:0.91989
# [123]	validation_0-mlogloss:0.91914
# [124]	validation_0-mlogloss:0.91875
# [125]	validation_0-mlogloss:0.91834
# [126]	validation_0-mlogloss:0.91753
# [127]	validation_0-mlogloss:0.91757
# [128]	validation_0-mlogloss:0.91716
# [129]	validation_0-mlogloss:0.91658
# [130]	validation_0-mlogloss:0.91598
# [131]	validation_0-mlogloss:0.91567
# [132]	validation_0-mlogloss:0.91489
# [133]	validation_0-mlogloss:0.91475
# [134]	validation_0-mlogloss:0.91453
# [135]	validation_0-mlogloss:0.91419
# [136]	validation_0-mlogloss:0.91335
# [137]	validation_0-mlogloss:0.91265
# [138]	validation_0-mlogloss:0.91223
# [139]	validation_0-mlogloss:0.91151
# ...
# [160]	validation_0-mlogloss:0.90018
# [161]	validation_0-mlogloss:0.90031
# [162]	validation_0-mlogloss:0.90018
# [163]	validation_0-mlogloss:0.90027
# [164]	validation_0-mlogloss:0.90015
# [165]	validation_0-mlogloss:0.89959
# [166]	validation_0-mlogloss:0.89966
# [167]	validation_0-mlogloss:0.89952
# [168]	validation_0-mlogloss:0.89937
# [169]	validation_0-mlogloss:0.89904
# [170]	validation_0-mlogloss:0.89864
# [171]	validation_0-mlogloss:0.89813
# [172]	validation_0-mlogloss:0.89767
# [173]	validation_0-mlogloss:0.89732
# [174]	validation_0-mlogloss:0.89733
# [175]	validation_0-mlogloss:0.89710
# [176]	validation_0-mlogloss:0.89690
# [177]	validation_0-mlogloss:0.89652
# [178]	validation_0-mlogloss:0.89634
# [179]	validation_0-mlogloss:0.89611
# [180]	validation_0-mlogloss:0.89592
# [181]	validation_0-mlogloss:0.89598
# [182]	validation_0-mlogloss:0.89587
# [183]	validation_0-mlogloss:0.89541
# [184]	validation_0-mlogloss:0.89543
# [185]	validation_0-mlogloss:0.89530
# [186]	validation_0-mlogloss:0.89493
# [187]	validation_0-mlogloss:0.89453
# [188]	validation_0-mlogloss:0.89453
# [189]	validation_0-mlogloss:0.89471
# [190]	validation_0-mlogloss:0.89476
# [191]	validation_0-mlogloss:0.89462
# [192]	validation_0-mlogloss:0.89444
# [193]	validation_0-mlogloss:0.89398
# [194]	validation_0-mlogloss:0.89389
# [195]	validation_0-mlogloss:0.89381
# [196]	validation_0-mlogloss:0.89336
# [197]	validation_0-mlogloss:0.89328
# [198]	validation_0-mlogloss:0.89329
# [199]	validation_0-mlogloss:0.89341
# [200]	validation_0-mlogloss:0.89310
# [201]	validation_0-mlogloss:0.89283
# [202]	validation_0-mlogloss:0.89261
# [203]	validation_0-mlogloss:0.89238
# [204]	validation_0-mlogloss:0.89223
# [205]	validation_0-mlogloss:0.89209
# [206]	validation_0-mlogloss:0.89186
# [207]	validation_0-mlogloss:0.89173
# [208]	validation_0-mlogloss:0.89143
# [209]	validation_0-mlogloss:0.89127
# [210]	validation_0-mlogloss:0.89118
# [211]	validation_0-mlogloss:0.89132
# [212]	validation_0-mlogloss:0.89090
# [213]	validation_0-mlogloss:0.89085
# [214]	validation_0-mlogloss:0.89043
# [215]	validation_0-mlogloss:0.89027
# [216]	validation_0-mlogloss:0.89022
# [217]	validation_0-mlogloss:0.88986
# [218]	validation_0-mlogloss:0.88968
# [219]	validation_0-mlogloss:0.88961
# [220]	validation_0-mlogloss:0.88965
# [221]	validation_0-mlogloss:0.88966
# [222]	validation_0-mlogloss:0.88932
# [223]	validation_0-mlogloss:0.88944
# [224]	validation_0-mlogloss:0.88904
# [225]	validation_0-mlogloss:0.88919
# [226]	validation_0-mlogloss:0.88924
# [227]	validation_0-mlogloss:0.88928
# [228]	validation_0-mlogloss:0.88928
# [229]	validation_0-mlogloss:0.88957
# [230]	validation_0-mlogloss:0.89001
# [231]	validation_0-mlogloss:0.88981
# [232]	validation_0-mlogloss:0.88972
# [233]	validation_0-mlogloss:0.88946
# [234]	validation_0-mlogloss:0.88913
# [235]	validation_0-mlogloss:0.88935
# [236]	validation_0-mlogloss:0.88912
# [237]	validation_0-mlogloss:0.88903
# [238]	validation_0-mlogloss:0.88896
# [239]	validation_0-mlogloss:0.88873
# [240]	validation_0-mlogloss:0.88880
# [241]	validation_0-mlogloss:0.88894
# [242]	validation_0-mlogloss:0.88887
# [243]	validation_0-mlogloss:0.88859
# [244]	validation_0-mlogloss:0.88864
# [245]	validation_0-mlogloss:0.88844
# [246]	validation_0-mlogloss:0.88847
# [247]	validation_0-mlogloss:0.88868
# [248]	validation_0-mlogloss:0.88880
# [249]	validation_0-mlogloss:0.88863
# [250]	validation_0-mlogloss:0.88876
# [251]	validation_0-mlogloss:0.88879
# [252]	validation_0-mlogloss:0.88870
# [253]	validation_0-mlogloss:0.88855
# [254]	validation_0-mlogloss:0.88847
# [255]	validation_0-mlogloss:0.88841
# [256]	validation_0-mlogloss:0.88817
# [257]	validation_0-mlogloss:0.88779
# [258]	validation_0-mlogloss:0.88768
# [259]	validation_0-mlogloss:0.88757
# [260]	validation_0-mlogloss:0.88765
# [261]	validation_0-mlogloss:0.88759
# [262]	validation_0-mlogloss:0.88762
# [263]	validation_0-mlogloss:0.88762
# [264]	validation_0-mlogloss:0.88756
# [265]	validation_0-mlogloss:0.88748
# [266]	validation_0-mlogloss:0.88728
# [267]	validation_0-mlogloss:0.88707
# [268]	validation_0-mlogloss:0.88715
# [269]	validation_0-mlogloss:0.88699
# [270]	validation_0-mlogloss:0.88702
# [271]	validation_0-mlogloss:0.88691
# [272]	validation_0-mlogloss:0.88671
# [273]	validation_0-mlogloss:0.88669
# [274]	validation_0-mlogloss:0.88670
# [275]	validation_0-mlogloss:0.88676
# [276]	validation_0-mlogloss:0.88688
# [277]	validation_0-mlogloss:0.88686
# [278]	validation_0-mlogloss:0.88707
# [279]	validation_0-mlogloss:0.88696
# [280]	validation_0-mlogloss:0.88707
# [281]	validation_0-mlogloss:0.88726
# [282]	validation_0-mlogloss:0.88707
# [283]	validation_0-mlogloss:0.88693
# [284]	validation_0-mlogloss:0.88692
# [285]	validation_0-mlogloss:0.88711
# [286]	validation_0-mlogloss:0.88722
# [287]	validation_0-mlogloss:0.88700
# [288]	validation_0-mlogloss:0.88697
# [289]	validation_0-mlogloss:0.88700
# [290]	validation_0-mlogloss:0.88708
# [291]	validation_0-mlogloss:0.88688
# [292]	validation_0-mlogloss:0.88704
# [293]	validation_0-mlogloss:0.88705
# [294]	validation_0-mlogloss:0.88710
# [295]	validation_0-mlogloss:0.88712
# [296]	validation_0-mlogloss:0.88698
# [297]	validation_0-mlogloss:0.88674
# [298]	validation_0-mlogloss:0.88661
# [299]	validation_0-mlogloss:0.88680
# [300]	validation_0-mlogloss:0.88675
# [301]	validation_0-mlogloss:0.88667
# [302]	validation_0-mlogloss:0.88688
# [303]	validation_0-mlogloss:0.88685
# [304]	validation_0-mlogloss:0.88688
# [305]	validation_0-mlogloss:0.88667
# [306]	validation_0-mlogloss:0.88670
# [307]	validation_0-mlogloss:0.88679
# [308]	validation_0-mlogloss:0.88673
# [309]	validation_0-mlogloss:0.88661
# [310]	validation_0-mlogloss:0.88643
# [311]	validation_0-mlogloss:0.88628
# [312]	validation_0-mlogloss:0.88617
# [313]	validation_0-mlogloss:0.88618
# [314]	validation_0-mlogloss:0.88624
# [315]	validation_0-mlogloss:0.88631
# [316]	validation_0-mlogloss:0.88630
# [317]	validation_0-mlogloss:0.88606
# [318]	validation_0-mlogloss:0.88601
# [319]	validation_0-mlogloss:0.88599
# [320]	validation_0-mlogloss:0.88605
# [321]	validation_0-mlogloss:0.88593
# [322]	validation_0-mlogloss:0.88584
# [323]	validation_0-mlogloss:0.88575
# [324]	validation_0-mlogloss:0.88563
# [325]	validation_0-mlogloss:0.88567
# [326]	validation_0-mlogloss:0.88554
# [327]	validation_0-mlogloss:0.88534
# [328]	validation_0-mlogloss:0.88537
# [329]	validation_0-mlogloss:0.88550
# [330]	validation_0-mlogloss:0.88570
# [331]	validation_0-mlogloss:0.88578
# [332]	validation_0-mlogloss:0.88573
# [333]	validation_0-mlogloss:0.88569
# [334]	validation_0-mlogloss:0.88579
# [335]	validation_0-mlogloss:0.88591
# [336]	validation_0-mlogloss:0.88587
# [337]	validation_0-mlogloss:0.88601
# [338]	validation_0-mlogloss:0.88579
# [339]	validation_0-mlogloss:0.88563
# [340]	validation_0-mlogloss:0.88557
# [341]	validation_0-mlogloss:0.88547
# [342]	validation_0-mlogloss:0.88550
# [343]	validation_0-mlogloss:0.88542
# [344]	validation_0-mlogloss:0.88564
# [345]	validation_0-mlogloss:0.88561
# [346]	validation_0-mlogloss:0.88567
# [347]	validation_0-mlogloss:0.88560
# [348]	validation_0-mlogloss:0.88563
# [349]	validation_0-mlogloss:0.88558
# [350]	validation_0-mlogloss:0.88553
# [351]	validation_0-mlogloss:0.88549
# [352]	validation_0-mlogloss:0.88537
# [353]	validation_0-mlogloss:0.88540
# [354]	validation_0-mlogloss:0.88537
# [355]	validation_0-mlogloss:0.88531
# [356]	validation_0-mlogloss:0.88523
# [357]	validation_0-mlogloss:0.88509
# [358]	validation_0-mlogloss:0.88523
# [359]	validation_0-mlogloss:0.88528
# [360]	validation_0-mlogloss:0.88532
# [361]	validation_0-mlogloss:0.88533
# [362]	validation_0-mlogloss:0.88538
# [363]	validation_0-mlogloss:0.88547
# [364]	validation_0-mlogloss:0.88532
# [365]	validation_0-mlogloss:0.88515
# [366]	validation_0-mlogloss:0.88525
# [367]	validation_0-mlogloss:0.88515
# [368]	validation_0-mlogloss:0.88523
# [369]	validation_0-mlogloss:0.88500
# [370]	validation_0-mlogloss:0.88497
# [371]	validation_0-mlogloss:0.88499
# [372]	validation_0-mlogloss:0.88487
# [373]	validation_0-mlogloss:0.88490
# [374]	validation_0-mlogloss:0.88495
# [375]	validation_0-mlogloss:0.88479
# [376]	validation_0-mlogloss:0.88479
# [377]	validation_0-mlogloss:0.88488
# [378]	validation_0-mlogloss:0.88484
# [379]	validation_0-mlogloss:0.88486
# [380]	validation_0-mlogloss:0.88490
# [381]	validation_0-mlogloss:0.88477
# [382]	validation_0-mlogloss:0.88475
# [383]	validation_0-mlogloss:0.88483
# [384]	validation_0-mlogloss:0.88491
# [385]	validation_0-mlogloss:0.88494
# [386]	validation_0-mlogloss:0.88512
# [387]	validation_0-mlogloss:0.88517
# [388]	validation_0-mlogloss:0.88511
# [389]	validation_0-mlogloss:0.88534
# [390]	validation_0-mlogloss:0.88528
# [391]	validation_0-mlogloss:0.88535
# [392]	validation_0-mlogloss:0.88514
# [393]	validation_0-mlogloss:0.88507
# [394]	validation_0-mlogloss:0.88495
# [395]	validation_0-mlogloss:0.88485
# [396]	validation_0-mlogloss:0.88493
# [397]	validation_0-mlogloss:0.88493
# [398]	validation_0-mlogloss:0.88475
# [399]	validation_0-mlogloss:0.88470
# [400]	validation_0-mlogloss:0.88467
# [401]	validation_0-mlogloss:0.88467
# [402]	validation_0-mlogloss:0.88472
# [403]	validation_0-mlogloss:0.88479
# [404]	validation_0-mlogloss:0.88458
# [405]	validation_0-mlogloss:0.88464
# [406]	validation_0-mlogloss:0.88464
# [407]	validation_0-mlogloss:0.88458
# [408]	validation_0-mlogloss:0.88455
# [409]	validation_0-mlogloss:0.88446
# [410]	validation_0-mlogloss:0.88450
# [411]	validation_0-mlogloss:0.88459
# [412]	validation_0-mlogloss:0.88455
# [413]	validation_0-mlogloss:0.88465
# [414]	validation_0-mlogloss:0.88480
# [415]	validation_0-mlogloss:0.88486
# [416]	validation_0-mlogloss:0.88486
# [417]	validation_0-mlogloss:0.88511
# [418]	validation_0-mlogloss:0.88507
# [419]	validation_0-mlogloss:0.88496
# [420]	validation_0-mlogloss:0.88495
# [421]	validation_0-mlogloss:0.88514
# [422]	validation_0-mlogloss:0.88514
# [423]	validation_0-mlogloss:0.88502
# [424]	validation_0-mlogloss:0.88517
# [425]	validation_0-mlogloss:0.88510
# [426]	validation_0-mlogloss:0.88513
# [427]	validation_0-mlogloss:0.88517
# [428]	validation_0-mlogloss:0.88532
# [429]	validation_0-mlogloss:0.88545
# [430]	validation_0-mlogloss:0.88524
# [431]	validation_0-mlogloss:0.88527
# [432]	validation_0-mlogloss:0.88542
# [433]	validation_0-mlogloss:0.88539
# [434]	validation_0-mlogloss:0.88534
# [435]	validation_0-mlogloss:0.88537
# [436]	validation_0-mlogloss:0.88543
# [437]	validation_0-mlogloss:0.88553
# [438]	validation_0-mlogloss:0.88553
# [439]	validation_0-mlogloss:0.88554
# [440]	validation_0-mlogloss:0.88556
# [441]	validation_0-mlogloss:0.88568
# [442]	validation_0-mlogloss:0.88547
# [443]	validation_0-mlogloss:0.88551
# [444]	validation_0-mlogloss:0.88545
# [445]	validation_0-mlogloss:0.88555
# [446]	validation_0-mlogloss:0.88553
# [447]	validation_0-mlogloss:0.88554
# [448]	validation_0-mlogloss:0.88561
# [449]	validation_0-mlogloss:0.88570
# [450]	validation_0-mlogloss:0.88570
# [451]	validation_0-mlogloss:0.88572
# [452]	validation_0-mlogloss:0.88576
# [453]	validation_0-mlogloss:0.88573
# [454]	validation_0-mlogloss:0.88592
# [455]	validation_0-mlogloss:0.88590
# [456]	validation_0-mlogloss:0.88581
# [457]	validation_0-mlogloss:0.88582
# [458]	validation_0-mlogloss:0.88577
# [459]	validation_0-mlogloss:0.88567
# [460]	validation_0-mlogloss:0.88577
# [461]	validation_0-mlogloss:0.88575
# [462]	validation_0-mlogloss:0.88582
# [463]	validation_0-mlogloss:0.88576
# [464]	validation_0-mlogloss:0.88573
# [465]	validation_0-mlogloss:0.88577
# [466]	validation_0-mlogloss:0.88576
# [467]	validation_0-mlogloss:0.88581
# [468]	validation_0-mlogloss:0.88606
# [469]	validation_0-mlogloss:0.88607
# [470]	validation_0-mlogloss:0.88618
# [471]	validation_0-mlogloss:0.88615
# [472]	validation_0-mlogloss:0.88629
# [473]	validation_0-mlogloss:0.88618
# [474]	validation_0-mlogloss:0.88606
# [475]	validation_0-mlogloss:0.88586
# [476]	validation_0-mlogloss:0.88590
# [477]	validation_0-mlogloss:0.88591
# [478]	validation_0-mlogloss:0.88585
# [479]	validation_0-mlogloss:0.88587
# [480]	validation_0-mlogloss:0.88586
# [481]	validation_0-mlogloss:0.88593
# [482]	validation_0-mlogloss:0.88596
# [483]	validation_0-mlogloss:0.88602
# [484]	validation_0-mlogloss:0.88598
# [485]	validation_0-mlogloss:0.88603
# [486]	validation_0-mlogloss:0.88597
# [487]	validation_0-mlogloss:0.88601
# [488]	validation_0-mlogloss:0.88616
# [489]	validation_0-mlogloss:0.88608
# [490]	validation_0-mlogloss:0.88594
# [491]	validation_0-mlogloss:0.88583
# [492]	validation_0-mlogloss:0.88590
# [493]	validation_0-mlogloss:0.88587
# [494]	validation_0-mlogloss:0.88597
# [495]	validation_0-mlogloss:0.88603
# [496]	validation_0-mlogloss:0.88606
# [497]	validation_0-mlogloss:0.88601
# [498]	validation_0-mlogloss:0.88609
# [499]	validation_0-mlogloss:0.88613
# [500]	validation_0-mlogloss:0.88612
# [501]	validation_0-mlogloss:0.88610
# [502]	validation_0-mlogloss:0.88625
# [503]	validation_0-mlogloss:0.88634
# [504]	validation_0-mlogloss:0.88627
# [505]	validation_0-mlogloss:0.88632
# [506]	validation_0-mlogloss:0.88625
# [507]	validation_0-mlogloss:0.88626
# [508]	validation_0-mlogloss:0.88623
# [509]	validation_0-mlogloss:0.88615
# [510]	validation_0-mlogloss:0.88626
# [511]	validation_0-mlogloss:0.88631
# [512]	validation_0-mlogloss:0.88638
# [513]	validation_0-mlogloss:0.88649
# [514]	validation_0-mlogloss:0.88674
# [515]	validation_0-mlogloss:0.88674
# [516]	validation_0-mlogloss:0.88678
# [517]	validation_0-mlogloss:0.88676
# [518]	validation_0-mlogloss:0.88678
# [519]	validation_0-mlogloss:0.88678
# [520]	validation_0-mlogloss:0.88670
# [521]	validation_0-mlogloss:0.88676
# [522]	validation_0-mlogloss:0.88679
# [523]	validation_0-mlogloss:0.88688
# [524]	validation_0-mlogloss:0.88682
# [525]	validation_0-mlogloss:0.88689
# [526]	validation_0-mlogloss:0.88687
# [527]	validation_0-mlogloss:0.88686
# [528]	validation_0-mlogloss:0.88703
# [529]	validation_0-mlogloss:0.88696
# [530]	validation_0-mlogloss:0.88703
# [531]	validation_0-mlogloss:0.88702
# [532]	validation_0-mlogloss:0.88699
# [533]	validation_0-mlogloss:0.88711
# [534]	validation_0-mlogloss:0.88726
# [535]	validation_0-mlogloss:0.88724
# [536]	validation_0-mlogloss:0.88726
# [537]	validation_0-mlogloss:0.88745
# [538]	validation_0-mlogloss:0.88751
# [539]	validation_0-mlogloss:0.88750
# [540]	validation_0-mlogloss:0.88748
# [541]	validation_0-mlogloss:0.88743
# [542]	validation_0-mlogloss:0.88752
# [543]	validation_0-mlogloss:0.88740
# [544]	validation_0-mlogloss:0.88744
# [545]	validation_0-mlogloss:0.88747
# [546]	validation_0-mlogloss:0.88758
# [547]	validation_0-mlogloss:0.88755
# [548]	validation_0-mlogloss:0.88762
# [549]	validation_0-mlogloss:0.88749
# [550]	validation_0-mlogloss:0.88751
# [551]	validation_0-mlogloss:0.88754
# [552]	validation_0-mlogloss:0.88762
# [553]	validation_0-mlogloss:0.88758
# [554]	validation_0-mlogloss:0.88776
# [555]	validation_0-mlogloss:0.88776
# [556]	validation_0-mlogloss:0.88777
# [557]	validation_0-mlogloss:0.88784
# [558]	validation_0-mlogloss:0.88787
# [559]	validation_0-mlogloss:0.88797
# [560]	validation_0-mlogloss:0.88800
# [561]	validation_0-mlogloss:0.88804
# [562]	validation_0-mlogloss:0.88803
# [563]	validation_0-mlogloss:0.88815
# [564]	validation_0-mlogloss:0.88799
# [565]	validation_0-mlogloss:0.88804
# [566]	validation_0-mlogloss:0.88798
# [567]	validation_0-mlogloss:0.88799
# [568]	validation_0-mlogloss:0.88808
# [569]	validation_0-mlogloss:0.88809
# [570]	validation_0-mlogloss:0.88814
# [571]	validation_0-mlogloss:0.88813
# [572]	validation_0-mlogloss:0.88811
# [573]	validation_0-mlogloss:0.88817
# [574]	validation_0-mlogloss:0.88816
# [575]	validation_0-mlogloss:0.88826
# [576]	validation_0-mlogloss:0.88819
# [577]	validation_0-mlogloss:0.88810
# [578]	validation_0-mlogloss:0.88814
# [579]	validation_0-mlogloss:0.88817
# [580]	validation_0-mlogloss:0.88831
# [581]	validation_0-mlogloss:0.88831
# [582]	validation_0-mlogloss:0.88838
# [583]	validation_0-mlogloss:0.88852
# [584]	validation_0-mlogloss:0.88853
# [585]	validation_0-mlogloss:0.88866
# [586]	validation_0-mlogloss:0.88874
# [587]	validation_0-mlogloss:0.88862
# [588]	validation_0-mlogloss:0.88857
# [589]	validation_0-mlogloss:0.88858
# [590]	validation_0-mlogloss:0.88859
# [591]	validation_0-mlogloss:0.88863
# [592]	validation_0-mlogloss:0.88861
# [593]	validation_0-mlogloss:0.88883
# [594]	validation_0-mlogloss:0.88890
# [595]	validation_0-mlogloss:0.88901
# [596]	validation_0-mlogloss:0.88894
# [597]	validation_0-mlogloss:0.88901
# [598]	validation_0-mlogloss:0.88903
# [599]	validation_0-mlogloss:0.88909
# Fold 5: Accuracy=0.6926, Macro-F1=0.6901
#
# ======  5-Fold Summary  ======
# Accuracy:  mean=0.6891  std=0.0128
# Macro-F1 : mean=0.6900  std=0.0104

# %%
# # final_model = CatBoostClassifier(**params_cat)
# final_model = LGBMClassifier(**params_lgb)
final_model = xgb.XGBClassifier(**params_xgb)
final_model.fit(X, y)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=256, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=600,
#               n_jobs=-1, num_class=18, num_parallel_tree=None, ...)

# %% [markdown]
# # <div style="color:#2d83ed; font-family: 'Segoe UI'; text-align: center; border-top:5px solid green; padding-left:10px; background-color:#F8F9F9; padding:10px; border-radius:5px;font-weight: bold">💾 Save the Model</div>

# %%
joblib.dump(final_model, f'model_catboost.joblib')
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [04:43:14] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# ['model_catboost.joblib']

# %% [markdown]
# # <div style="color:#2d83ed; font-family: 'Segoe UI'; text-align: center; border-top:5px solid green; padding-left:10px; background-color:#F8F9F9; padding:10px; border-radius:5px;font-weight: bold">🌟 Predict</div>
#
# Not needed as we are just trainig the model. It is only kept here to be used for testing only, whenever needed.

# %%
# def predict(sequence: pl.DataFrame, demographics: pl.DataFrame) -> str:
#     # data =sequence
#     data = sequence.join(demographics,on="subject",how="left")
#     # print(data.schema)
#     data = feature_engineering_imu(data)
#     cleaned_data = feature_engineering_stat(data)

#     pdf = cleaned_data.to_pandas().drop(columns=["sequence_id"])

#     pdf = robustscaler.transform(pdf)
#     predictions = final_model.predict(pdf).ravel()
#     predictions = le.inverse_transform(predictions)
#     return predictions[0]

# %% [markdown]
# # <div style="color:#2d83ed; font-family: 'Segoe UI'; text-align: center; border-top:5px solid green; padding-left:10px; background-color:#F8F9F9; padding:10px; border-radius:5px;font-weight: bold">🪐 Inference Server</div>
# Not needed as we are just trainig the model. It is only kept here to be used for testing only, whenever needed.

# %%
# inference_server = kaggle_evaluation.cmi_inference_server.CMIInferenceServer(predict)

# if os.getenv('KAGGLE_IS_COMPETITION_RERUN'):
#     inference_server.serve()
# else:
#     inference_server.run_local_gateway(
#         data_paths=(
#             '/kaggle/input/cmi-detect-behavior-with-sensor-data/test.csv',
#             '/kaggle/input/cmi-detect-behavior-with-sensor-data/test_demographics.csv',
#         )
#     )
